# %% [markdown]
# # Chicago to Columbus NS
# This notebook selects the route from the Landers Intermodal yard in Chicago IL to the Rickenbacker Intermodal yard in Columbus OH.

# %%
import geopandas as gpd
import networkx as nx
from shapely import geometry, ops
import numpy as np
import matplotlib.pyplot as plt
import requests
import pandas as pd
import folium
import time
from requests.auth import AuthBase
import os
from scipy.spatial import distance

# %%
data = gpd.read_file("North_American_Rail_Network_Lines.geojson")
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /opt/conda/share/proj failed

# %%
ns_data = data[data[['RROWNER1', 'RROWNER2', 'RROWNER3', 'TRKRGHTS1', 'TRKRGHTS2', 'TRKRGHTS3', 'TRKRGHTS4', 'TRKRGHTS5', 'TRKRGHTS6', 'TRKRGHTS7', 'TRKRGHTS8', 'TRKRGHTS9']].isin(['NS']).any(axis=1)]

# %%
start = ns_data[ns_data['TOFRANODE'].isin([414008])]

# %% [markdown]
# verify that we got a single entry from the database

# %%
start
# Out:
#         OBJECTID  FRAARCID  FRFRANODE  TOFRANODE STFIPS CNTYFIPS STCNTYFIPS  \
# 190111    190112    491467     413960     414008     17      031      17031
#
#        STATEAB COUNTRY  FRADISTRCT  ... YARDNAME PASSNGR STRACNET TRACKS NET  \
# 190111      IL      US           4  ...     None       C     None    1.0   M
#
#            MILES        KM TIMEZONE ShapeSTLength  \
# 190111  0.398881  0.641938        C    860.260919
#
#                                                  geometry
# 190111  LINESTRING (-87.70019 41.75082, -87.69737 41.7...
#
# [1 rows x 35 columns]

# %%
end = ns_data[ns_data['FRFRANODE'].isin([442152])]

# %% [markdown]
# verfy

# %%
end
# Out:
#        OBJECTID  FRAARCID  FRFRANODE  TOFRANODE STFIPS CNTYFIPS STCNTYFIPS  \
# 97926     97927    398984     442152     442168     39      129      39129
#
#       STATEAB COUNTRY  FRADISTRCT  ...                 YARDNAME PASSNGR  \
# 97926      OH      US           2  ...  RICKENBACKER INTERMODAL    None
#
#       STRACNET TRACKS NET     MILES        KM TIMEZONE ShapeSTLength  \
# 97926     None    2.0   M  0.962261  1.548612        E    2020.47711
#
#                                                 geometry
# 97926  LINESTRING (-82.95814 39.77872, -82.95797 39.7...
#
# [1 rows x 35 columns]

# %% [markdown]
# ## Determine the shortest route
# We use the networkx library to determine the "optimal" route between two nodes on a graph. For this optimization, the graph consists of all nodes and "edges" or lines for which NOrfolk Southern has owns or has rights. This was determiend above.

# %%
from_nodes = list(ns_data.FRFRANODE)

# %%
to_nodes = list(ns_data.TOFRANODE)

# %% [markdown]
# The nodes in the graph is a union of all of the to and from nodes in the dataset.

# %%
all_nodes = list(set(from_nodes) | set(to_nodes))

# %% [markdown]
# Out of curiosity, how many are there? Quite a few, but this graph is not highly interconnected.

# %%
len(all_nodes)
# Out:
# 29689

# %% [markdown]
# The next step is to actually create a graph.

# %%
G=nx.Graph()

# %%
G.add_nodes_from(all_nodes)

# %% [markdown]
# We need to add the edges between the nodes and give them a weighting of the distane between the nodes - this will result in the shortest route.

# %%
edges = ns_data[['FRFRANODE','TOFRANODE', 'MILES']].to_records(index=False).tolist()

# %%
G.add_weighted_edges_from(edges)

# %%
nx.astar_path_length(G, 413960, 442152)
# Out:
# 344.06318362000013

# %%
route = nx.astar_path(G, 414008, 442152)

# %%
route_data = ns_data[(ns_data['FRFRANODE'].isin(route) & ns_data['TOFRANODE'].isin(route))]

# %%
fig = folium.Figure(height=600)
map = folium.Map(location=[40.75, -85.0], zoom_start=10,tile=None)
folium.TileLayer(tiles='http://{s}.tiles.openrailwaymap.org/standard/{z}/{x}/{y}.png', attr='OpenStreetMap attribution').add_to(map)
folium.TileLayer(tiles='http://{s}.google.com/vt/lyrs=s,h&x={x}&y={y}&z={z}', attr='Google Maps').add_to(map)
folium.GeoJson(route_data).add_to(map)
map.add_to(fig)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5b51d71f5e1980b87dbcb78d06f698ca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5b51d71f5e1980b87dbcb78d06f698ca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5b51d71f5e1980b87dbcb78d06f698ca = L.map(
#                 &quot;map_5b51d71f5e1980b87dbcb78d06f698ca&quot;,
#                 {
#                     center: [40.75, -85.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_43631d887688d4658da41dd6ff555a27 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5b51d71f5e1980b87dbcb78d06f698ca);
#
#
#             var tile_layer_1791c2d4f581a95c30f9571ecd42c116 = L.tileLayer(
#                 &quot;http://{s}.tiles.openrailwaymap.org/standard/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;OpenStreetMap attribution&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5b51d71f5e1980b87dbcb78d06f698ca);
#
#
#             var tile_layer_da4ff0c83b2f49b0e11ea524b3045cbb = L.tileLayer(
#                 &quot;http://{s}.google.com/vt/lyrs=s,h\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Maps&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5b51d71f5e1980b87dbcb78d06f698ca);
#
#
#
#         function geo_json_5b51ecc36debb8b56dbc5603c4dd78fc_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_5b51ecc36debb8b56dbc5603c4dd78fc = L.geoJson(null, {
#                 onEachFeature: geo_json_5b51ecc36debb8b56dbc5603c4dd78fc_onEachFeature,
#
#         });
#
#         function geo_json_5b51ecc36debb8b56dbc5603c4dd78fc_add (data) {
#             geo_json_5b51ecc36debb8b56dbc5603c4dd78fc
#                 .addData(data)
#                 .addTo(map_5b51d71f5e1980b87dbcb78d06f698ca);
#         }
#             geo_json_5b51ecc36debb8b56dbc5603c4dd78fc_add({&quot;bbox&quot;: [-87.69388164583542, 39.7787207386044, -82.94544750880164, 41.75809599976254], &quot;features&quot;: [{&quot;bbox&quot;: [-83.03842103865024, 40.71903856052758, -82.97469771176965, 40.78983569553943], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-82.97469771176965, 40.78983569553943], [-82.97811407486375, 40.786033950736396], [-82.97853026702984, 40.78557081097628], [-82.97857118259608, 40.7855252784723], [-82.97900812943848, 40.78506471234114], [-82.9802481117544, 40.783706637412166], [-82.98068505949512, 40.78318702547332], [-82.98172428361639, 40.782076944170306], [-82.98738096957061, 40.77575893451651], [-82.9880422940114, 40.775038564354], [-82.99195119169768, 40.770692718503135], [-82.99764330541007, 40.76432747016956], [-82.99973949807442, 40.76196641552902], [-83.00000000052366, 40.76167300043655], [-83.00059510026341, 40.761032100271414], [-83.00254768105992, 40.75887653989115], [-83.00955895369904, 40.75113641122613], [-83.01066903423497, 40.74990823786409], [-83.01272386307376, 40.747629030017706], [-83.01358594750583, 40.74664885270099], [-83.02656443931986, 40.73221780954371], [-83.02812327415428, 40.73049364306728], [-83.0362599247403, 40.72144767039054], [-83.03842103865024, 40.71903856052758]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;89650&quot;, &quot;properties&quot;: {&quot;BRANCH&quot;: &quot;#N\\A&quot;, &quot;CNTYFIPS&quot;: &quot;033&quot;, &quot;COUNTRY&quot;: &quot;US&quot;, &quot;DIVISION&quot;: &quot;GREAT LAKES&quot;, &quot;FRAARCID&quot;: 390627, &quot;FRADISTRCT&quot;: 2, &quot;FRFRANODE&quot;: 441963, &quot;KM&quot;: 9.52734712, &quot;MILES&quot;: 5.9200072, &quot;NET&quot;: &quot;M&quot;, &quot;OBJECTID&quot;: 89651, &quot;PASSNGR&quot;: null, &quot;RROWNER1&quot;: &quot;NS&quot;, &quot;RROWNER2&quot;: null, &quot;RROWNER3&quot;: null, &quot;STATEAB&quot;: &quot;OH&quot;, &quot;STCNTYFIPS&quot;: &quot;39033&quot;, &quot;STFIPS&quot;: &quot;39&quot;, &quot;STRACNET&quot;: null, &quot;SUBDIV&quot;: &quot;SANDUSKY DISTRICT&quot;, &quot;ShapeSTLength&quot;: 12592.26204154051, &quot;TIMEZONE&quot;: &quot;E&quot;, &quot;TOFRANODE&quot;: 441539, &quot;TRACKS&quot;: 1.0, &quot;TRKRGHTS1&quot;: null, &quot;TRKRGHTS2&quot;: null, &quot;TRKRGHTS3&quot;: null, &quot;TRKRGHTS4&quot;: null, &quot;TRKRGHTS5&quot;: null, &quot;TRKRGHTS6&quot;: null, &quot;TRKRGHTS7&quot;: null, &quot;TRKRGHTS8&quot;: null, &quot;TRKRGHTS9&quot;: null, &quot;YARDNAME&quot;: null}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-84.58783651630729, 40.864181919500815, -84.52249

# %% [markdown]
# This results is a pretty messed up route where you need to turn around in Bucyrus. We can try to create a udpated grpah that removes a node in the "u-turn" part of the track (442,113) from the graph and have it solve again.

# %%
G.remove_node(442113)

# %%
nx.astar_path_length(G, 414008, 442152)
# Out:
# 378.97785170000003

# %%
route2 = nx.astar_path(G, 414008, 442152)

# %% [markdown]
# This may be a little to simplistic for a query.

# %%
route2_data = ns_data[(ns_data['FRFRANODE'].isin(route2) & ns_data['TOFRANODE'].isin(route2))]

# %% [markdown]
# Instead, lets loop through all pairs and select lines that have one of each on the ends.

# %%
ends = [route2[2], route2[3]]
ends
# Out:
# [414137, 414094]

# %%
ends=[442219, 442214]

# %%
test1 = ns_data[(ns_data['FRFRANODE'].isin(ends) & ns_data['TOFRANODE'].isin(ends))]
test1
# Out:
#         OBJECTID  FRAARCID  FRFRANODE  TOFRANODE STFIPS CNTYFIPS STCNTYFIPS  \
# 99083      99084    400141     442214     442219     39      049      39049
# 116461    116462    417543     442214     442219     39      049      39049
#
#        STATEAB COUNTRY  FRADISTRCT  ... YARDNAME PASSNGR STRACNET TRACKS NET  \
# 99083       OH      US           2  ...     None    None     None    2.0   M
# 116461      OH      US           2  ...     None    None     None    0.0   O
#
#            MILES        KM TIMEZONE ShapeSTLength  \
# 99083   0.337571  0.543269        E    709.467835
# 116461  0.345486  0.556007        E    725.977182
#
#                                                  geometry
# 99083   LINESTRING (-82.95259 39.84879, -82.95258 39.8...
# 116461  LINESTRING (-82.95259 39.84879, -82.95253 39.8...
#
# [2 rows x 35 columns]

# %%
route2_data[route2_data['FRAARCID']==501627]
# Out:
#         OBJECTID  FRAARCID  FRFRANODE  TOFRANODE STFIPS CNTYFIPS STCNTYFIPS  \
# 200261    200262    501627     414137     414094     17      031      17031
#
#        STATEAB COUNTRY  FRADISTRCT  ... YARDNAME PASSNGR STRACNET TRACKS NET  \
# 200261      IL      US           4  ...  LANDERS    None     None    0.0   Y
#
#            MILES        KM TIMEZONE ShapeSTLength  \
# 200261  0.154189  0.248144        C    332.276893
#
#                                                  geometry
# 200261  LINESTRING (-9760785.207 5124710.936, -9760887...
#
# [1 rows x 35 columns]

# %%
fig = folium.Figure(height=600)
map = folium.Map(location=[40.75, -85.0], zoom_start=10,tile=None)
folium.TileLayer(tiles='http://{s}.tiles.openrailwaymap.org/standard/{z}/{x}/{y}.png', attr='OpenStreetMap attribution').add_to(map)
folium.TileLayer(tiles='http://{s}.google.com/vt/lyrs=s,h&x={x}&y={y}&z={z}', attr='Google Maps').add_to(map)
folium.GeoJson(route2_data).add_to(map)
map.add_to(fig)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fb519ac1596b602a84ce8a97563be46f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fb519ac1596b602a84ce8a97563be46f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fb519ac1596b602a84ce8a97563be46f = L.map(
#                 &quot;map_fb519ac1596b602a84ce8a97563be46f&quot;,
#                 {
#                     center: [40.75, -85.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8624b1654921c86a4bf455b7aad1cb4c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fb519ac1596b602a84ce8a97563be46f);
#
#
#             var tile_layer_71adf0c69ea752dabc6bdfeeba092096 = L.tileLayer(
#                 &quot;http://{s}.tiles.openrailwaymap.org/standard/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;OpenStreetMap attribution&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fb519ac1596b602a84ce8a97563be46f);
#
#
#             var tile_layer_afc878e73efb6487cd94070afd01b3d8 = L.tileLayer(
#                 &quot;http://{s}.google.com/vt/lyrs=s,h\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Maps&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fb519ac1596b602a84ce8a97563be46f);
#
#
#
#         function geo_json_8b45cbdde65a407b205b32aeb305f6f5_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_8b45cbdde65a407b205b32aeb305f6f5 = L.geoJson(null, {
#                 onEachFeature: geo_json_8b45cbdde65a407b205b32aeb305f6f5_onEachFeature,
#
#         });
#
#         function geo_json_8b45cbdde65a407b205b32aeb305f6f5_add (data) {
#             geo_json_8b45cbdde65a407b205b32aeb305f6f5
#                 .addData(data)
#                 .addTo(map_fb519ac1596b602a84ce8a97563be46f);
#         }
#             geo_json_8b45cbdde65a407b205b32aeb305f6f5_add({&quot;bbox&quot;: [-87.69388164583542, 39.7787207386044, -82.84336316473018, 41.75809599976254], &quot;features&quot;: [{&quot;bbox&quot;: [-82.93860829587877, 40.9559698270541, -82.93766674647667, 40.9576317000287], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-82.93766674647667, 40.9576317000287], [-82.93770057613195, 40.957571986990004], [-82.93770641068973, 40.95756169153947], [-82.93782598723381, 40.95735063241453], [-82.93836103729177, 40.956406246993765], [-82.93860829587877, 40.9559698270541]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;89304&quot;, &quot;properties&quot;: {&quot;BRANCH&quot;: &quot;#N\\A&quot;, &quot;CNTYFIPS&quot;: &quot;033&quot;, &quot;COUNTRY&quot;: &quot;US&quot;, &quot;DIVISION&quot;: &quot;GREAT LAKES&quot;, &quot;FRAARCID&quot;: 390281, &quot;FRADISTRCT&quot;: 2, &quot;FRFRANODE&quot;: 442333, &quot;KM&quot;: 0.20085952, &quot;MILES&quot;: 0.12480807, &quot;NET&quot;: &quot;M&quot;, &quot;OBJECTID&quot;: 89305, &quot;PASSNGR&quot;: null, &quot;RROWNER1&quot;: &quot;NS&quot;, &quot;RROWNER2&quot;: null, &quot;RROWNER3&quot;: null, &quot;STATEAB&quot;: &quot;OH&quot;, &quot;STCNTYFIPS&quot;: &quot;39033&quot;, &quot;STFIPS&quot;: &quot;39&quot;, &quot;STRACNET&quot;: null, &quot;SUBDIV&quot;: &quot;SANDUSKY DISTRICT&quot;, &quot;ShapeSTLength&quot;: 266.44656170890306, &quot;TIMEZONE&quot;: &quot;E&quot;, &quot;TOFRANODE&quot;: 442327, &quot;TRACKS&quot;: 1.0, &quot;TRKRGHTS1&quot;: &quot;WE&quot;, &quot;TRKRGHTS2&quot;: null, &quot;TRKRGHTS3&quot;: null, &quot;TRKRGHTS4&quot;: null, &quot;TRKRGHTS5&quot;: null, &quot;TRKRGHTS6&quot;: null, &quot;TRKRGHTS7&quot;: null, &quot;TRKRGHTS8&quot;: null, &quot;TRKRGHTS9&quot;: null, &quot;YARDNAME&quot;: null}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-83.97868470186066, 41.10489566097943, -83.97816077474255, 41.10490653381523], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-83.97868470186066, 41.10489566097943], [-83.9786247788413, 41.1048969057747], [-83.97816077474255, 41.10490653381523]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;89335&quot;, &quot;properties&quot;: {&quot;BRANCH&quot;: &quot;#N\\A&quot;, &quot;CNTYFIPS&quot;: &quot;137&quot;, &quot;COUNTRY&quot;: &quot;US&quot;, &quot;DIVISION&quot;: &quot;GREAT LAKES&quot;, &quot;FRAARCID&quot;: 390312, &quot;FRADISTRCT&quot;: 2, &quot;FRFRANODE&quot;: 435807, &quot;KM&quot;: 0.0440273, &quot;MILES&quot;: 0.02735724, &quot;NET&quot;: &quot;M&quot;, &quot;OBJECTID&quot;: 89336, &quot;PASSNGR&quot;: null, &quot;RROWNER1&quot;: &quot;

# %%
len(route2_data.geometry.get_coordinates())
# Out:
# 3238

# %% [markdown]
# This route looks good, we can now move onto the next phase, simplification and segmentation. There are 3238 cooridnataes in this route. This can be reduced with simplify. Before we simplify, we need to convert the coordinate reference system to be in meters.

# %%
route2_data = route2_data.to_crs(3857)
simple_route = route2_data.simplify(1, preserve_topology=False)
simple_route = simple_route.to_crs(4326)

# %%
fig = folium.Figure(height=600)
map = folium.Map(location=[40.75, -85.0], zoom_start=10,tile=None)
folium.TileLayer(tiles='http://{s}.tiles.openrailwaymap.org/standard/{z}/{x}/{y}.png', attr='OpenStreetMap attribution').add_to(map)
folium.TileLayer(tiles='http://{s}.google.com/vt/lyrs=s,h&x={x}&y={y}&z={z}', attr='Google Maps').add_to(map)
folium.GeoJson(simple_route).add_to(map)
map.add_to(fig)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2e90f45481f79172805f2c52430a26d9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2e90f45481f79172805f2c52430a26d9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2e90f45481f79172805f2c52430a26d9 = L.map(
#                 &quot;map_2e90f45481f79172805f2c52430a26d9&quot;,
#                 {
#                     center: [40.75, -85.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6508f7e602ef79a720c87dd905f536eb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2e90f45481f79172805f2c52430a26d9);
#
#
#             var tile_layer_a2db552460906b508a82f8a961dc2290 = L.tileLayer(
#                 &quot;http://{s}.tiles.openrailwaymap.org/standard/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;OpenStreetMap attribution&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2e90f45481f79172805f2c52430a26d9);
#
#
#             var tile_layer_16ccbec98a05ed0a4bfc175273727e56 = L.tileLayer(
#                 &quot;http://{s}.google.com/vt/lyrs=s,h\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Maps&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2e90f45481f79172805f2c52430a26d9);
#
#
#
#         function geo_json_b6ca913234f15d49fd718c4e3106ec56_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_b6ca913234f15d49fd718c4e3106ec56 = L.geoJson(null, {
#                 onEachFeature: geo_json_b6ca913234f15d49fd718c4e3106ec56_onEachFeature,
#
#         });
#
#         function geo_json_b6ca913234f15d49fd718c4e3106ec56_add (data) {
#             geo_json_b6ca913234f15d49fd718c4e3106ec56
#                 .addData(data)
#                 .addTo(map_2e90f45481f79172805f2c52430a26d9);
#         }
#             geo_json_b6ca913234f15d49fd718c4e3106ec56_add({&quot;bbox&quot;: [-87.69388164583542, 39.7787207386044, -82.84336316473018, 41.75809599976253], &quot;features&quot;: [{&quot;bbox&quot;: [-82.93860829587877, 40.9559698270541, -82.93766674647665, 40.9576317000287], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-82.93766674647665, 40.9576317000287], [-82.93860829587877, 40.9559698270541]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;89304&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-83.97868470186067, 41.10489566097942, -83.97816077474255, 41.10490653381523], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-83.97868470186067, 41.10489566097942], [-83.97816077474255, 41.10490653381523]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;89335&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-83.97883815207746, 41.10489247757951, -83.97868470186067, 41.10489566097942], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-83.97883815207746, 41.10489247757951], [-83.97868470186067, 41.10489566097942]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;89336&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-82.9449499229826, 40.89837532175219, -82.93860829587877, 40.9559698270541], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-82.94491226291095, 40.89837532175219], [-82.9449499229826, 40.904280241065074], [-82.94493397249641, 40.90571553423594], [-82.94484265245957, 40.9064879783506], [-82.94466181350805, 40.9072018164941], [-82.94443338450772, 40.90783951285366], [-82.94409074280385, 40.908496243706075], [-82.94379430055672, 40.90896220004281], [-82.94140481154535, 40.9119963639082], [-82.94082622194222, 40.912953263108705], [-82.94037970175386, 40.914306391095984], [-82.94021436952073, 40.91567627827109], [-82.94012450026307, 40.92135619961426], [-82.94008373112223, 40.92814107396282], [-82.93996637341691, 40.93581124317835], [-82.93988370685116, 40.943770754669615], [-82.93981285133482, 40.94694747218988], [-82.93980104208211, 40.9482228836831], [-82.93982700069886, 40.950118999860514], [-82.93978867767052, 40.9519071313271], [-82.93975060706877, 40.952506754321625], [-82.93967446406867, 40.95323962867165], [-82.9395316966172, 40.95394394882289], [-82.93934134001522, 40.95457212693844], [-82.93907483861652, 40.95522885748684], [-82.93860829587877, 40.9559698270541]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;89649&quot;, &quot;properties&quot;: {}, &quot;type&quo

# %% [markdown]
# There does not appear to be any significnat difference. How many points do we currently have?

# %%
coords = simple_route.geometry.get_coordinates()

# %%
len(coords)
# Out:
# 1410

# %% [markdown]
# To better support the estimation of gradient (and may also assist in curvature), we should segmentize the data to have a maximum distance between points.

# %%
simple_route = simple_route.to_crs(3857)
simple2_route = simple_route.segmentize(max_segment_length=100)
simple2_route = simple2_route.to_crs(4326)
len(simple2_route.geometry.get_coordinates())
# Out:
# 9351

# %% [markdown]
# big oof here, setting max segemetn length to 100 meteres give us 9351 coordinates - too many fo rthis short route.

# %%
simple_route = simple_route.to_crs(3857)
simple2_route = simple_route.segmentize(max_segment_length=200)
simple2_route = simple2_route.to_crs(4326)
len(simple2_route.geometry.get_coordinates())
# Out:
# 5124

# %% [markdown]
# Doubling this distance to 200 meters reduces to 5124 coordinates. We can try to get the necessary altitudes at this point. This is a relative long process of querrying. The data in the dataframe consists of a number of line segments. In this case there are 284

# %%
len(simple2_route)
# Out:
# 284

# %% [markdown]
# We will take the geometry of each row in the data frame and create a few new data elements or columns. The first will be to create the 'xyz' data.
# The geometric data uses the 4326 crs, or lat-long system. Using this information we can query the UGS website to get the altitude. This data will get stores in a "z" column fo rnow and then after converting the the 3857 crs, we can get distances in meters to make the xyz column.

# %% [markdown]
# Instead, lets do some piece work to better understand what we have. The first thing to notice is the list is not ordered from beginning to end. All of the segments are there, but they were taken "randomly" - by order of their OBJECTID.

# %%
row = route2_data.iloc[0]

# %% [markdown]
# route2 holds the ordered list of nodes. The prior system of selecting the lines that have the nodes resulted in the "randomness" of the results. Instead, we nee to create a new data frame incrementally.

# %%
route2[0]
# Out:
# 414008

# %%
start
# Out:
#         OBJECTID  FRAARCID  FRFRANODE  TOFRANODE STFIPS CNTYFIPS STCNTYFIPS  \
# 190111    190112    491467     413960     414008     17      031      17031
#
#        STATEAB COUNTRY  FRADISTRCT  ... YARDNAME PASSNGR STRACNET TRACKS NET  \
# 190111      IL      US           4  ...     None       C     None    1.0   M
#
#            MILES        KM TIMEZONE ShapeSTLength  \
# 190111  0.398881  0.641938        C    860.260919
#
#                                                  geometry
# 190111  LINESTRING (-87.70019 41.75082, -87.69737 41.7...
#
# [1 rows x 35 columns]

# %%
route2[1]
# Out:
# 414159

# %% [markdown]
# The odd thing here is that we "started" with the line above, but it is not actually part of the route.

# %%
route2[-1]
# Out:
# 442152

# %%
end
# Out:
#        OBJECTID  FRAARCID  FRFRANODE  TOFRANODE STFIPS CNTYFIPS STCNTYFIPS  \
# 97926     97927    398984     442152     442168     39      129      39129
#
#       STATEAB COUNTRY  FRADISTRCT  ...                 YARDNAME PASSNGR  \
# 97926      OH      US           2  ...  RICKENBACKER INTERMODAL    None
#
#       STRACNET TRACKS NET     MILES        KM TIMEZONE ShapeSTLength  \
# 97926     None    2.0   M  0.962261  1.548612        E    2020.47711
#
#                                                 geometry
# 97926  LINESTRING (-82.95814 39.77872, -82.95797 39.7...
#
# [1 rows x 35 columns]

# %%
route2[-2]
# Out:
# 442168

# %% [markdown]
# The route ends with both nodes, though there seems to always be a bit of confusion between FR and TO nodes - in general, it is best to assume they are just end points and don't assume a direction.
#
# A route consists of the ordered list of nodes where each contigiuous pair is the FR and TO nodes, but not necessarily in any order.

# %% [markdown]
# This seems to give reasonable answers that may not require much if any filtering to "smooth" out the results.

# %%
def curve(p1, p2, p3):
    v1=p2-p1
    v2=p3-p2
    v3=p1-p3
    d1=np.linalg.norm(v1)
    d2=np.linalg.norm(v2)
    d3=np.linalg.norm(v3) * 3.28084
    dp = np.dot(v1,v2)
    d = dp/(d1*d2)
    if d>1.0:
        d=1.0
    angle=np.arccos(d)*(100/d3)
    return angle*180/np.pi

# %%
URL ="http://score-web-1:8000"

# %%
URL1 = URL+"/api-token-auth/"

# %%
payload = {'username':'locomotives', 'password':'locomotives'}

# %%
URL1
# Out:
# 'http://score-web-1:8000/api-token-auth/'

# %%
t = requests.post(URL1, data=payload )

# %%
token = t.json().get('token')

# %%
URL2 = URL+"/api/line/add/"

# %%
class TokenAuth(AuthBase):
    """ Implements a custom authentication scheme. """

    def __init__(self, token):
        self.token = token

    def __call__(self, r):
        """ Attach an API token to a custom auth header. """
        r.headers['Authorization'] = "Token " + f'{self.token}'
        return r

# %%
URL3 = URL+'/api/railroad/'

# %%
r = requests.get(URL3, auth=TokenAuth(token))

# %%
railroads=r.json()['results']
railroads
# Out:
# [{'id': 1, 'code': 'BNSF', 'name': 'Burlington Northern and Santa Fe'},
#  {'id': 2, 'code': 'CN', 'name': 'Canadian National Railway'},
#  {'id': 3, 'code': 'CP', 'name': 'Canadian Pacific Railway'},
#  {'id': 4, 'code': 'CSXT', 'name': 'CSX Transportation'},
#  {'id': 5, 'code': 'NS', 'name': 'Norfolk Southern Railway'},
#  {'id': 6, 'code': 'KCS', 'name': 'Kansas City Southern Railway'},
#  {'id': 7, 'code': 'UP', 'name': 'Union Pacific'}]

# %%
URL4 = URL + "/api/line/"

# %%
route2_data.crs
# Out:
# <Projected CRS: EPSG:3857>
# Name: WGS 84 / Pseudo-Mercator
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: World between 85.06°S and 85.06°N.
# - bounds: (-180.0, -85.06, 180.0, 85.06)
# Coordinate Operation:
# - name: Popular Visualisation Pseudo-Mercator
# - method: Popular Visualisation Pseudo Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
route2_xy = route2_data.copy()

# %%
route2_ll = route2_data.to_crs(4326)

# %% [markdown]
# let's make a function to add each entry in a dataframe. It will take in a row, get the elevations, calculate gradients and curvatures and put the data into the database.

# %%
API_KEY=

# %% [markdown]
# Lets modify the above to get all of the elevations in a single call.

# %%
def get_alt(lat, lng):
    st = ""
    # print(lng)
    for i in range(len(lng)):
        st+=str(lat[i])+','+str(lng[i])+'|'
    st=st[:-1]
    url = "https://maps.googleapis.com/maps/api/elevation/json?locations=" + st + "&key=" + API_KEY
    # print(url)
    response = requests.get(url)
    # result = response.json()['results']['elevation']
    # print(response.status)
    # print(response.json()['results'])
    results = response.json()['results']
    res = []
    for rec in results:
        res.append(rec['elevation'])
    # should put in a test for response status before returning an actual value
    return res

# %%
def create_row(rowxy, rowll, rights, url, token=None):
    p = np.array(rowxy.geometry.coords)
    pxy = p[:,0:2]
    # we want the interpoint distance between the points - the offset of 1, diagonal of the cdist matrix
    dist = np.diagonal(distance.cdist(pxy, pxy), offset=1)
    lng,lat = rowll.geometry.xy
    ele=get_alt(lat, lng)
    lnglat = np.array(rowll.geometry.coords)
    xyz = np.append(pxy.T, [ele], axis=0).T
    dele = np.diff(ele)
    gradient = np.divide(dele, dist)
    curvature=[]
    if (len(pxy)>2):
        for i in range(len(pxy)-2):
            curvature.append(curve(pxy[i],pxy[i+1],pxy[i+2]))
        curvature.append(curvature[-1])
    else:
        curvature = [0.0]
    line = {
        "fra_id" : rowxy['FRAARCID'],
        "from_node" : rowxy['FRFRANODE'],
        "to_node" : rowxy['TOFRANODE'],
        "rights" : rights,
        "xyz": xyz.tolist(),
        "lnglat": lnglat.tolist(),
        "gradient": gradient.tolist(),
        "curvature": curvature
    }
    requests.post(url, data=line, auth=TokenAuth(token))
    print(line['fra_id'])

# %% [markdown]
# Test to add one row

# %% [raw]
# create_row(route2_xy.iloc[0], route2_ll.iloc[0], [5], URL2, token)

# %% [markdown]
# Lets add all of the segments ot the database.

# %%
for i in range(len(route2_xy)):
    # first test to see if it already exists
    fra_id = route2_xy.iloc[i]['FRAARCID']
    response = requests.get(URL4+str(fra_id), auth=TokenAuth(token))
    if (response.status_code == 204):
        create_row(route2_xy.iloc[i], route2_ll.iloc[i], [5], URL2, token)
# Out:
# 500999
# 501323
# 501326
# 501329
# 501330
# 501345
# 501627
# 502245
# 502249
# 502254
# 502295
# 502338
# 502371
# 502372
# 502373
# 502661
# 502813
# 504425
# 505387
# 505390
# 505396
# 507067
# 507375
# 519032
# 523795
# 530848
# 530850
# 530853

# %% [markdown]
# The next step to saving a route is to include an  ordered list of nodes used make the route.

# %%
URL5 = URL + "/api/route/add/"

# %%
URL6 = URL + "/api/yard/all/"

# %%
response = requests.get(URL6, auth=TokenAuth(token))

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'results': [{'id': 1, 'name': 'Landers Yard'},
#   {'id': 2, 'name': 'Rickenbacker'}]}

# %%
URL7 = URL + "/api/yard/"

# %%
response = requests.get(URL7+'1', auth=TokenAuth(token))

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'results': {'id': 1,
#   'code': 'LND',
#   'name': 'Landers Yard',
#   'city': 'Chicago',
#   'state': 'IL',
#   'location': 414008,
#   'owner': 7}}

# %%
route = {
    'origin': 1,
    'destination': 2,
    'owner': 5,
    'path': route2
}

# %%
res = requests.post(URL5, data=route, auth=TokenAuth(token))

# %%
res.json()
# Out:
# {'results': 1}

# %%
URL8 = URL + "/api/route/detail/"

# %%
response = requests.get(URL8+'1', auth=TokenAuth(token))

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'results': 1}

# %% [raw]
# for i in range(len(route2_xy)):
#     # first test to see if it already exists
#     fra_id = route2_xy.iloc[i]['FRAARCID']
#     response = requests.get(URL4+str(fra_id), auth=TokenAuth(token))
#     print(fra_id, response.status_code)

# %% [markdown]
# This will delete a recond from the Lines table - there happened to be a main and siding line with the same from and to nodes - this made for odd results

# %%
response = requests.get(URL+'/api/line/delete/417543', auth=TokenAuth(token))

# %%
response
# Out:
# <Response [200]>
