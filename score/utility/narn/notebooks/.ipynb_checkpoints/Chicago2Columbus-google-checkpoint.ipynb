# %% [markdown]
# # Chicago to Columbus NS
# This notebook selects the route from the Landers Intermodal yard in Chicago IL to the Rickenbacker Intermodal yard in Columbus OH.

# %%
import geopandas as gpd
import networkx as nx
from shapely import geometry, ops
import numpy as np
import matplotlib.pyplot as plt
import requests
import pandas as pd
import folium
import time
from requests.auth import AuthBase
import os
from scipy.spatial import distance

# %%
data = gpd.read_file("North_American_Rail_Network_Lines.geojson")
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /opt/conda/share/proj failed

# %% [markdown]
# The column used to all be capitalized, now they are lower case.

# %%
data.columns
# Out:
# Index(['objectid', 'fraarcid', 'frfranode', 'tofranode', 'stfips', 'cntyfips',
#        'stcntyfips', 'stateab', 'country', 'fradistrct', 'rrowner1',
#        'rrowner2', 'rrowner3', 'trkrghts1', 'trkrghts2', 'trkrghts3',
#        'trkrghts4', 'trkrghts5', 'trkrghts6', 'trkrghts7', 'trkrghts8',
#        'trkrghts9', 'division', 'subdiv', 'branch', 'yardname', 'passngr',
#        'stracnet', 'tracks', 'net', 'miles', 'km', 'timezone', 'shape_Length',
#        'geometry'],
#       dtype='object')

# %%
ns_data = data[data[['rrowner1', 'rrowner2', 'rrowner3', 'trkrghts1', 'trkrghts2', 'trkrghts3', 'trkrghts4', 'trkrghts5', 'trkrghts6', 'trkrghts7', 'trkrghts8', 'trkrghts9']].isin(['NS']).any(axis=1)]

# %%
start = ns_data[ns_data['tofranode'].isin([414008])]

# %% [markdown]
# verify that we got a single entry from the database

# %%
start
# Out:
#         objectid  fraarcid  frfranode  tofranode stfips cntyfips stcntyfips  \
# 190111    190889    491467     413960     414008     17      031      17031
#
#        stateab country  fradistrct  ... yardname passngr stracnet tracks net  \
# 190111      IL      US           4  ...     None       C     None    1.0   M
#
#            miles        km timezone shape_Length  \
# 190111  0.398881  0.641938        C     0.007136
#
#                                                  geometry
# 190111  MULTILINESTRING ((-87.70019 41.75082, -87.6973...
#
# [1 rows x 35 columns]

# %%
end = ns_data[ns_data['frfranode'].isin([442152])]

# %% [markdown]
# verfy

# %%
end
# Out:
#        objectid  fraarcid  frfranode  tofranode stfips cntyfips stcntyfips  \
# 97926     98513    398984     442152     442168     39      129      39129
#
#       stateab country  fradistrct  ...                 yardname passngr  \
# 97926      OH      US           2  ...  RICKENBACKER INTERMODAL    None
#
#       stracnet tracks net     miles        km timezone shape_Length  \
# 97926     None    2.0   M  0.962261  1.548612        E     0.013964
#
#                                                 geometry
# 97926  MULTILINESTRING ((-82.95814 39.77872, -82.9579...
#
# [1 rows x 35 columns]

# %% [markdown]
# ## Determine the shortest route
# We use the networkx library to determine the "optimal" route between two nodes on a graph. For this optimization, the graph consists of all nodes and "edges" or lines for which NOrfolk Southern has owns or has rights. This was determiend above.

# %%
from_nodes = list(ns_data.frfranode)

# %%
to_nodes = list(ns_data.tofranode)

# %% [markdown]
# The nodes in the graph is a union of all of the to and from nodes in the dataset.

# %%
all_nodes = list(set(from_nodes) | set(to_nodes))

# %% [markdown]
# Out of curiosity, how many are there? Quite a few, but this graph is not highly interconnected.

# %%
len(all_nodes)
# Out:
# 29689

# %% [markdown]
# The next step is to actually create a graph.

# %%
G=nx.Graph()

# %%
G.add_nodes_from(all_nodes)

# %% [markdown]
# We need to add the edges between the nodes and give them a weighting of the distane between the nodes - this will result in the shortest route.

# %%
edges = ns_data[['frfranode','tofranode', 'miles']].to_records(index=False).tolist()

# %%
G.add_weighted_edges_from(edges)

# %%
nx.astar_path_length(G, 413960, 442152)
# Out:
# 344.06318362000013

# %%
route = nx.astar_path(G, 414008, 442152)

# %%
route_data = ns_data[(ns_data['frfranode'].isin(route) & ns_data['tofranode'].isin(route))]

# %%
fig = folium.Figure(height=600)
map = folium.Map(location=[40.75, -85.0], zoom_start=10,tile=None)
folium.TileLayer(tiles='http://{s}.tiles.openrailwaymap.org/standard/{z}/{x}/{y}.png', attr='OpenStreetMap attribution').add_to(map)
folium.TileLayer(tiles='http://{s}.google.com/vt/lyrs=s,h&x={x}&y={y}&z={z}', attr='Google Maps').add_to(map)
folium.GeoJson(route_data).add_to(map)
map.add_to(fig)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_58b9a5cc12066955c48d5767f0d7e3b9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_58b9a5cc12066955c48d5767f0d7e3b9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_58b9a5cc12066955c48d5767f0d7e3b9 = L.map(
#                 &quot;map_58b9a5cc12066955c48d5767f0d7e3b9&quot;,
#                 {
#                     center: [40.75, -85.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ceef675671581080a0c74bf599a2d9c9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_58b9a5cc12066955c48d5767f0d7e3b9);
#
#
#             var tile_layer_1ca825049f2376c9e2e74179fb3b12fa = L.tileLayer(
#                 &quot;http://{s}.tiles.openrailwaymap.org/standard/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;OpenStreetMap attribution&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_58b9a5cc12066955c48d5767f0d7e3b9);
#
#
#             var tile_layer_5d00887d8f0afa420997e68356d73a6d = L.tileLayer(
#                 &quot;http://{s}.google.com/vt/lyrs=s,h\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Maps&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_58b9a5cc12066955c48d5767f0d7e3b9);
#
#
#
#         function geo_json_89f62a42c91832f31a7b76fe1440388f_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_89f62a42c91832f31a7b76fe1440388f = L.geoJson(null, {
#                 onEachFeature: geo_json_89f62a42c91832f31a7b76fe1440388f_onEachFeature,
#
#         });
#
#         function geo_json_89f62a42c91832f31a7b76fe1440388f_add (data) {
#             geo_json_89f62a42c91832f31a7b76fe1440388f
#                 .addData(data)
#                 .addTo(map_58b9a5cc12066955c48d5767f0d7e3b9);
#         }
#             geo_json_89f62a42c91832f31a7b76fe1440388f_add({&quot;bbox&quot;: [-87.69388164599997, 39.77872073900005, -82.94544750899996, 41.758096], &quot;features&quot;: [{&quot;bbox&quot;: [-83.03842103899996, 40.71903856100005, -82.97469771199997, 40.78983569600007], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-82.97469771199997, 40.78983569600007], [-82.97811407499995, 40.786033951000036], [-82.97853026699994, 40.78557081100007], [-82.97857118299999, 40.78552527800008], [-82.97900812899996, 40.785064712000064], [-82.98024811199997, 40.78370663700008], [-82.98068505899994, 40.783187025000075], [-82.98172428399994, 40.78207694400004], [-82.98738096999995, 40.775758935000056], [-82.98804229399997, 40.775038564000056], [-82.99195119199999, 40.77069271900007], [-82.99764330499994, 40.76432747000007], [-82.99973949799994, 40.761966416000064], [-83.00000000099999, 40.761673], [-83.00059509999994, 40.76103210000008], [-83.00254768099995, 40.758876540000074], [-83.00955895399994, 40.75113641100006], [-83.01066903399999, 40.749908238000046], [-83.01272386299996, 40.74762903000004], [-83.01358594799996, 40.74664885300007], [-83.02656443899997, 40.732217810000066], [-83.02812327399994, 40.730493643000045], [-83.03625992499997, 40.72144767000003], [-83.03842103899996, 40.71903856100005]]], &quot;type&quot;: &quot;MultiLineString&quot;}, &quot;id&quot;: &quot;89650&quot;, &quot;properties&quot;: {&quot;branch&quot;: &quot;#N\\A&quot;, &quot;cntyfips&quot;: &quot;033&quot;, &quot;country&quot;: &quot;US&quot;, &quot;division&quot;: &quot;GREAT LAKES&quot;, &quot;fraarcid&quot;: 390627, &quot;fradistrct&quot;: 2, &quot;frfranode&quot;: 441963, &quot;km&quot;: 9.52734712, &quot;miles&quot;: 5.9200072, &quot;net&quot;: &quot;M&quot;, &quot;objectid&quot;: 90201, &quot;passngr&quot;: null, &quot;rrowner1&quot;: &quot;NS&quot;, &quot;rrowner2&quot;: null, &quot;rrowner3&quot;: null, &quot;shape_Length&quot;: 0.09525317664321098, &quot;stateab&quot;: &quot;OH&quot;, &quot;stcntyfips&quot;: &quot;39033&quot;, &quot;stfips&quot;: &quot;39&quot;, &quot;stracnet&quot;: null, &quot;subdiv&quot;: &quot;SANDUSKY DISTRICT&quot;, &quot;timezone&quot;: &quot;E&quot;, &quot;tofranode&quot;: 441539, &quot;tracks&quot;: 1.0, &quot;trkrghts1&quot;: null, &quot;trkrghts2&quot;: null, &quot;trkrghts3&quot;: null, &quot;trkrghts4&quot;: null, &quot;trkrghts5&quot;: null, &quot;trkrghts6&quot;: null, &quot;trkrghts7&quot;: null, &quot;trkrghts8&quot;: null, &quot;trkrghts9&quot;: null, &quot;yardname&quot;: null}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-84.58783651599998, 40.86418192000008, -84.522

# %% [markdown]
# This results is a pretty messed up route where you need to turn around in Bucyrus. We can try to create a udpated grpah that removes a node in the "u-turn" part of the track (442,113) from the graph and have it solve again.

# %%
G.remove_node(442113)

# %%
nx.astar_path_length(G, 414008, 442152)
# Out:
# 378.97785170000003

# %%
route2 = nx.astar_path(G, 414008, 442152)

# %% [markdown]
# This may be a little to simplistic for a query.

# %%
route2_data = ns_data[(ns_data['frfranode'].isin(route2) & ns_data['tofranode'].isin(route2))]

# %% [markdown]
# Instead, lets loop through all pairs and select lines that have one of each on the ends.

# %%
ends = [route2[2], route2[3]]
ends
# Out:
# [414137, 414094]

# %%
ends=[442219, 442214]

# %%
test1 = ns_data[(ns_data['frfranode'].isin(ends) & ns_data['tofranode'].isin(ends))]
test1
# Out:
#         objectid  fraarcid  frfranode  tofranode stfips cntyfips stcntyfips  \
# 99083      99670    400141     442214     442219     39      049      39049
# 116461    117066    417543     442214     442219     39      049      39049
#
#        stateab country  fradistrct  ... yardname passngr stracnet tracks net  \
# 99083       OH      US           2  ...     None    None     None    2.0   M
# 116461      OH      US           2  ...     None    None     None    0.0   O
#
#            miles        km timezone shape_Length  \
# 99083   0.337571  0.543269        E     0.004901
# 116461  0.345486  0.556007        E     0.005089
#
#                                                  geometry
# 99083   MULTILINESTRING ((-82.95259 39.84879, -82.9525...
# 116461  MULTILINESTRING ((-82.95259 39.84879, -82.9525...
#
# [2 rows x 35 columns]

# %%
route2_data[route2_data['fraarcid']==501627]
# Out:
#         objectid  fraarcid  frfranode  tofranode stfips cntyfips stcntyfips  \
# 200261    201039    501627     414137     414094     17      031      17031
#
#        stateab country  fradistrct  ... yardname passngr stracnet tracks net  \
# 200261      IL      US           4  ...  LANDERS    None     None    0.0   Y
#
#            miles        km timezone shape_Length  \
# 200261  0.154189  0.248144        C     0.002916
#
#                                                  geometry
# 200261  MULTILINESTRING ((-87.68263 41.75742, -87.6835...
#
# [1 rows x 35 columns]

# %%
fig = folium.Figure(height=600)
map = folium.Map(location=[40.75, -85.0], zoom_start=10,tile=None)
folium.TileLayer(tiles='http://{s}.tiles.openrailwaymap.org/standard/{z}/{x}/{y}.png', attr='OpenStreetMap attribution').add_to(map)
folium.TileLayer(tiles='http://{s}.google.com/vt/lyrs=s,h&x={x}&y={y}&z={z}', attr='Google Maps').add_to(map)
folium.GeoJson(route2_data).add_to(map)
map.add_to(fig)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_747ee94623818a6328de9f91dc22ec93 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_747ee94623818a6328de9f91dc22ec93&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_747ee94623818a6328de9f91dc22ec93 = L.map(
#                 &quot;map_747ee94623818a6328de9f91dc22ec93&quot;,
#                 {
#                     center: [40.75, -85.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e890621a75638bc2e0ea7e1f7306ca47 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_747ee94623818a6328de9f91dc22ec93);
#
#
#             var tile_layer_48faa8e779621ba8f62361e5a52dbb5f = L.tileLayer(
#                 &quot;http://{s}.tiles.openrailwaymap.org/standard/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;OpenStreetMap attribution&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_747ee94623818a6328de9f91dc22ec93);
#
#
#             var tile_layer_0597e685942fc702e0c1d1ece7aa2a39 = L.tileLayer(
#                 &quot;http://{s}.google.com/vt/lyrs=s,h\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Maps&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_747ee94623818a6328de9f91dc22ec93);
#
#
#
#         function geo_json_02ae02d80b4dd071a0bd5a3789d54860_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_02ae02d80b4dd071a0bd5a3789d54860 = L.geoJson(null, {
#                 onEachFeature: geo_json_02ae02d80b4dd071a0bd5a3789d54860_onEachFeature,
#
#         });
#
#         function geo_json_02ae02d80b4dd071a0bd5a3789d54860_add (data) {
#             geo_json_02ae02d80b4dd071a0bd5a3789d54860
#                 .addData(data)
#                 .addTo(map_747ee94623818a6328de9f91dc22ec93);
#         }
#             geo_json_02ae02d80b4dd071a0bd5a3789d54860_add({&quot;bbox&quot;: [-87.69388164599997, 39.77872073900005, -82.84336316499997, 41.758096], &quot;features&quot;: [{&quot;bbox&quot;: [-82.93860829599998, 40.95596982700005, -82.93766674599993, 40.957631700000036], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-82.93766674599993, 40.957631700000036], [-82.93770057599994, 40.95757198700005], [-82.93770641099997, 40.95756169200007], [-82.93782598699994, 40.95735063200004], [-82.93836103699994, 40.956406247000075], [-82.93860829599998, 40.95596982700005]]], &quot;type&quot;: &quot;MultiLineString&quot;}, &quot;id&quot;: &quot;89304&quot;, &quot;properties&quot;: {&quot;branch&quot;: &quot;#N\\A&quot;, &quot;cntyfips&quot;: &quot;033&quot;, &quot;country&quot;: &quot;US&quot;, &quot;division&quot;: &quot;GREAT LAKES&quot;, &quot;fraarcid&quot;: 390281, &quot;fradistrct&quot;: 2, &quot;frfranode&quot;: 442333, &quot;km&quot;: 0.20085952, &quot;miles&quot;: 0.12480807, &quot;net&quot;: &quot;M&quot;, &quot;objectid&quot;: 89855, &quot;passngr&quot;: null, &quot;rrowner1&quot;: &quot;NS&quot;, &quot;rrowner2&quot;: null, &quot;rrowner3&quot;: null, &quot;shape_Length&quot;: 0.0019100623736844138, &quot;stateab&quot;: &quot;OH&quot;, &quot;stcntyfips&quot;: &quot;39033&quot;, &quot;stfips&quot;: &quot;39&quot;, &quot;stracnet&quot;: null, &quot;subdiv&quot;: &quot;SANDUSKY DISTRICT&quot;, &quot;timezone&quot;: &quot;E&quot;, &quot;tofranode&quot;: 442327, &quot;tracks&quot;: 1.0, &quot;trkrghts1&quot;: &quot;WE&quot;, &quot;trkrghts2&quot;: null, &quot;trkrghts3&quot;: null, &quot;trkrghts4&quot;: null, &quot;trkrghts5&quot;: null, &quot;trkrghts6&quot;: null, &quot;trkrghts7&quot;: null, &quot;trkrghts8&quot;: null, &quot;trkrghts9&quot;: null, &quot;yardname&quot;: null}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-83.97868470199995, 41.10489566100006, -83.97816077499994, 41.104906534000065], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-83.97868470199995, 41.10489566100006], [-83.97862477899997, 41.10489690600008], [-83.97816077499994, 41.104906534000065]]], &quot;type&quot;: &quot;MultiLineString&quot;}, &quot;id&quot;: &quot;89335&quot;, &quot;properties&quot;: {&quot;branch&quot;: &quot;#N\\A&quot;, &quot;cntyfips&quot;: &quot;137&quot;, &quot;country&quot;: &quot;US&quot;, &quot;division&quot;: &quot;GREAT LAKES&quot;, &quot;fraarcid&quot;: 390312, &quot;fradistrct&quot;: 2, &quot;frfranode&quot;: 435807, &quot;km&quot;: 0.0440273, &quot;miles&quot;: 0.02735724, &quot;net&quot;: &quot;M&quot;, &quot;objectid&quot;: 89886, &quot;passngr&quot;: null, &quot;rrow

# %%
len(route2_data.geometry.get_coordinates())
# Out:
# 3238

# %% [markdown]
# This route looks good, we can now move onto the next phase, simplification and segmentation. There are 3238 cooridnataes in this route. This can be reduced with simplify. Before we simplify, we need to convert the coordinate reference system to be in meters.

# %%
route2_data = route2_data.to_crs(3857)
simple_route = route2_data.simplify(1, preserve_topology=False)
simple_route = simple_route.to_crs(4326)

# %%
fig = folium.Figure(height=600)
map = folium.Map(location=[40.75, -85.0], zoom_start=10,tile=None)
folium.TileLayer(tiles='http://{s}.tiles.openrailwaymap.org/standard/{z}/{x}/{y}.png', attr='OpenStreetMap attribution').add_to(map)
folium.TileLayer(tiles='http://{s}.google.com/vt/lyrs=s,h&x={x}&y={y}&z={z}', attr='Google Maps').add_to(map)
folium.GeoJson(simple_route).add_to(map)
map.add_to(fig)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b905d4c7ec2f8394c93c875f5d6b0b38 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b905d4c7ec2f8394c93c875f5d6b0b38&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b905d4c7ec2f8394c93c875f5d6b0b38 = L.map(
#                 &quot;map_b905d4c7ec2f8394c93c875f5d6b0b38&quot;,
#                 {
#                     center: [40.75, -85.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5575b5ee0d563436280d9fa18f497f15 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b905d4c7ec2f8394c93c875f5d6b0b38);
#
#
#             var tile_layer_9f17ae400bef3168a06f4f936eb2a870 = L.tileLayer(
#                 &quot;http://{s}.tiles.openrailwaymap.org/standard/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;OpenStreetMap attribution&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b905d4c7ec2f8394c93c875f5d6b0b38);
#
#
#             var tile_layer_b90adc1efbf9074065ac9bd194b5fab9 = L.tileLayer(
#                 &quot;http://{s}.google.com/vt/lyrs=s,h\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Maps&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b905d4c7ec2f8394c93c875f5d6b0b38);
#
#
#
#         function geo_json_5f447ddd4b4026b36a3ed47b1390bf50_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_5f447ddd4b4026b36a3ed47b1390bf50 = L.geoJson(null, {
#                 onEachFeature: geo_json_5f447ddd4b4026b36a3ed47b1390bf50_onEachFeature,
#
#         });
#
#         function geo_json_5f447ddd4b4026b36a3ed47b1390bf50_add (data) {
#             geo_json_5f447ddd4b4026b36a3ed47b1390bf50
#                 .addData(data)
#                 .addTo(map_b905d4c7ec2f8394c93c875f5d6b0b38);
#         }
#             geo_json_5f447ddd4b4026b36a3ed47b1390bf50_add({&quot;bbox&quot;: [-87.69388164599995, 39.77872073900004, -82.84336316499997, 41.75809600000001], &quot;features&quot;: [{&quot;bbox&quot;: [-82.93860829599997, 40.95596982700005, -82.93766674599993, 40.957631700000036], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-82.93766674599993, 40.957631700000036], [-82.93860829599997, 40.95596982700005]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;89304&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-83.97868470199995, 41.10489566100006, -83.97816077499994, 41.104906534000065], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-83.97868470199995, 41.10489566100006], [-83.97816077499994, 41.104906534000065]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;89335&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-83.97883815199997, 41.10489247800006, -83.97868470199995, 41.10489566100006], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-83.97883815199997, 41.10489247800006], [-83.97868470199995, 41.10489566100006]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;89336&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-82.94494992299997, 40.89837532200005, -82.93860829599997, 40.95596982700005], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-82.94491226299994, 40.89837532200005], [-82.94494992299997, 40.90428024100003], [-82.94493397199993, 40.90571553400008], [-82.94484265199996, 40.90648797800003], [-82.94466181399996, 40.907201816000054], [-82.94443338499995, 40.907839513000056], [-82.94409074299995, 40.90849624400005], [-82.94379430099995, 40.908962200000076], [-82.94140481199996, 40.91199636400005], [-82.94082622199993, 40.91295326300008], [-82.94037970199996, 40.914306391000025], [-82.94021436999998, 40.91567627800003], [-82.94012449999995, 40.921356200000055], [-82.94008373099996, 40.92814107400005], [-82.93996637299995, 40.935811243000046], [-82.93988370699996, 40.94377075500006], [-82.93981285099994, 40.94694747200003], [-82.93980104199994, 40.94822288400007], [-82.93982700099997, 40.950119], [-82.93978867799994, 40.951907131000034], [-82.93975060699994, 40.95250675400007], [-82.93967446399995, 40.95323962900005], [-82.93953169699995, 40.95394394900006], [-82.93934133999993, 40.954572127000056], [-82.93907483899993, 40.95522885700006], [-82.93860829599997, 40.95596982700005]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;89649&quot;, &quot;properties&quot;: {}, &q

# %% [markdown]
# There does not appear to be any significnat difference. How many points do we currently have?

# %%
coords = simple_route.geometry.get_coordinates()

# %%
len(coords)
# Out:
# 1410

# %% [markdown]
# To better support the estimation of gradient (and may also assist in curvature), we should segmentize the data to have a maximum distance between points.

# %%
simple_route = simple_route.to_crs(3857)
simple2_route = simple_route.segmentize(max_segment_length=100)
simple2_route = simple2_route.to_crs(4326)
len(simple2_route.geometry.get_coordinates())
# Out:
# 9351

# %% [markdown]
# big oof here, setting max segemetn length to 100 meteres give us 9351 coordinates - too many fo rthis short route.

# %%
simple_route = simple_route.to_crs(3857)
simple2_route = simple_route.segmentize(max_segment_length=200)
simple2_route = simple2_route.to_crs(4326)
len(simple2_route.geometry.get_coordinates())
# Out:
# 5124

# %% [markdown]
# Doubling this distance to 200 meters reduces to 5124 coordinates. We can try to get the necessary altitudes at this point. This is a relative long process of querrying. The data in the dataframe consists of a number of line segments. In this case there are 284

# %%
len(simple2_route)
# Out:
# 284

# %% [markdown]
# We will take the geometry of each row in the data frame and create a few new data elements or columns. The first will be to create the 'xyz' data.
# The geometric data uses the 4326 crs, or lat-long system. Using this information we can query the UGS website to get the altitude. This data will get stores in a "z" column fo rnow and then after converting the the 3857 crs, we can get distances in meters to make the xyz column.

# %% [markdown]
# Instead, lets do some piece work to better understand what we have. The first thing to notice is the list is not ordered from beginning to end. All of the segments are there, but they were taken "randomly" - by order of their OBJECTID.

# %%
row = route2_data.iloc[0]

# %% [markdown]
# route2 holds the ordered list of nodes. The prior system of selecting the lines that have the nodes resulted in the "randomness" of the results. Instead, we nee to create a new data frame incrementally.

# %%
route2[0]
# Out:
# 414008

# %%
start
# Out:
#         objectid  fraarcid  frfranode  tofranode stfips cntyfips stcntyfips  \
# 190111    190889    491467     413960     414008     17      031      17031
#
#        stateab country  fradistrct  ... yardname passngr stracnet tracks net  \
# 190111      IL      US           4  ...     None       C     None    1.0   M
#
#            miles        km timezone shape_Length  \
# 190111  0.398881  0.641938        C     0.007136
#
#                                                  geometry
# 190111  MULTILINESTRING ((-87.70019 41.75082, -87.6973...
#
# [1 rows x 35 columns]

# %%
route2[1]
# Out:
# 414159

# %% [markdown]
# The odd thing here is that we "started" with the line above, but it is not actually part of the route.

# %%
route2[-1]
# Out:
# 442152

# %%
end
# Out:
#        objectid  fraarcid  frfranode  tofranode stfips cntyfips stcntyfips  \
# 97926     98513    398984     442152     442168     39      129      39129
#
#       stateab country  fradistrct  ...                 yardname passngr  \
# 97926      OH      US           2  ...  RICKENBACKER INTERMODAL    None
#
#       stracnet tracks net     miles        km timezone shape_Length  \
# 97926     None    2.0   M  0.962261  1.548612        E     0.013964
#
#                                                 geometry
# 97926  MULTILINESTRING ((-82.95814 39.77872, -82.9579...
#
# [1 rows x 35 columns]

# %%
route2[-2]
# Out:
# 442168

# %% [markdown]
# The route ends with both nodes, though there seems to always be a bit of confusion between FR and TO nodes - in general, it is best to assume they are just end points and don't assume a direction.
#
# A route consists of the ordered list of nodes where each contigiuous pair is the FR and TO nodes, but not necessarily in any order.

# %% [markdown]
# This seems to give reasonable answers that may not require much if any filtering to "smooth" out the results.

# %%
def curve(p1, p2, p3):
    v1=p2-p1
    v2=p3-p2
    v3=p1-p3
    d1=np.linalg.norm(v1)
    d2=np.linalg.norm(v2)
    d3=np.linalg.norm(v3)
    num = 1746.375*2*np.linalg.norm(np.cross(v1,v2))
    d = num/(d1*d2*d3)
    return d

# %%
URL ="http://score-web-1:8000"

# %%
URL1 = URL+"/api-token-auth/"

# %%
payload = {'username':'locomotives', 'password':'locomotives'}

# %%
URL1
# Out:
# 'http://score-web-1:8000/api-token-auth/'

# %%
t = requests.post(URL1, data=payload )

# %%
token = t.json().get('token')

# %%
URL2 = URL+"/api/line/add/"

# %%
class TokenAuth(AuthBase):
    """ Implements a custom authentication scheme. """

    def __init__(self, token):
        self.token = token

    def __call__(self, r):
        """ Attach an API token to a custom auth header. """
        r.headers['Authorization'] = "Token " + f'{self.token}'
        return r

# %%
URL3 = URL+'/api/railroad/'

# %%
r = requests.get(URL3, auth=TokenAuth(token))

# %%
railroads=r.json()['results']
railroads
# Out:
# [{'id': 1, 'code': 'BNSF', 'name': 'Burlington Northern and Santa Fe'},
#  {'id': 2, 'code': 'CN', 'name': 'Canadian National Railway'},
#  {'id': 3, 'code': 'CP', 'name': 'Canadian Pacific Railway'},
#  {'id': 4, 'code': 'CSXT', 'name': 'CSX Transportation'},
#  {'id': 5, 'code': 'NS', 'name': 'Norfolk Southern Railway'},
#  {'id': 6, 'code': 'KCS', 'name': 'Kansas City Southern Railway'},
#  {'id': 7, 'code': 'UP', 'name': 'Union Pacific'}]

# %%
URL4 = URL + "/api/line/"

# %%
route2_data.crs
# Out:
# <Projected CRS: EPSG:3857>
# Name: WGS 84 / Pseudo-Mercator
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: World between 85.06°S and 85.06°N.
# - bounds: (-180.0, -85.06, 180.0, 85.06)
# Coordinate Operation:
# - name: Popular Visualisation Pseudo-Mercator
# - method: Popular Visualisation Pseudo Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
route2_xy = route2_data.copy()

# %%
route2_ll = route2_data.to_crs(4326)

# %% [markdown]
# let's make a function to add each entry in a dataframe. It will take in a row, get the elevations, calculate gradients and curvatures and put the data into the database.

# %%
API_KEY='AIzaSyDUJLn3rph0_rVjdu0-yne0hig58qrTGXQ'

# %% [markdown]
# Lets modify the above to get all of the elevations in a single call.

# %%
def get_alt(lat, lng):
    st = ""
    # print(lng)
    for i in range(len(lng)):
        st+=str(lat[i])+','+str(lng[i])+'|'
    st=st[:-1]
    url = "https://maps.googleapis.com/maps/api/elevation/json?locations=" + st + "&key=" + API_KEY
    # print(url)
    response = requests.get(url)
    # result = response.json()['results']['elevation']
    # print(response.status)
    # print(response.json()['results'])
    results = response.json()['results']
    res = []
    for rec in results:
        res.append(rec['elevation'])
    # should put in a test for response status before returning an actual value
    return res

# %%
def create_row(rowxy, rowll, rights, url, token=None):
    p = np.array(rowxy.geometry.coords)
    pxy = p[:,0:2]
    # we want the interpoint distance between the points - the offset of 1, diagonal of the cdist matrix
    dist = np.diagonal(distance.cdist(pxy, pxy), offset=1)
    lng,lat = rowll.geometry.xy
    ele=get_alt(lat, lng)
    lnglat = np.array(rowll.geometry.coords)
    xyz = np.append(pxy.T, [ele], axis=0).T
    dele = np.diff(ele)
    gradient = np.divide(dele, dist)
    curvature=[]
    if (len(pxy)>2):
        for i in range(len(pxy)-2):
            curvature.append(curve(pxy[i],pxy[i+1],pxy[i+2]))
        curvature.append(curvature[-1])
    else:
        curvature = [0.0]
    line = {
        "fra_id" : rowxy['fraarcid'],
        "from_node" : rowxy['frfranode'],
        "to_node" : rowxy['tofranode'],
        "length" : rowxy['km'],
        "rights" : rights,
        "xyz": xyz.tolist(),
        "lnglat": lnglat.tolist(),
        "gradient": gradient.tolist(),
        "curvature": curvature
    }
    requests.post(url, data=line, auth=TokenAuth(token))
    print(line['fra_id'])

# %% [markdown]
# we need to explode the multiliestrings that are being used now to be linestrings

# %%
route2_xy2 = route2_xy.explode(index_parts=True)

# %%
np.array(route2_xy2.iloc[0].geometry.coords)
# Out:
# array([[-9232578.82974693,  5006094.35639577],
#        [-9232582.59568531,  5006085.55440148],
#        [-9232583.24523454,  5006084.03686789],
#        [-9232596.55637396,  5006052.9256389 ],
#        [-9232656.11786751,  5005913.72010093],
#        [-9232683.64261349,  5005849.39099204]])

# %% [markdown]
# Test to add one row

# %%
route2_ll2 = route2_ll.explode(index_parts=True)
np.array(route2_ll2.iloc[0].geometry.coords)
# Out:
# array([[-82.93766675,  40.9576317 ],
#        [-82.93770058,  40.95757199],
#        [-82.93770641,  40.95756169],
#        [-82.93782599,  40.95735063],
#        [-82.93836104,  40.95640625],
#        [-82.9386083 ,  40.95596983]])

# %% [raw]
# create_row(route2_xy2.iloc[0], route2_ll2.iloc[0], [5], URL2, token)

# %% [markdown]
# Lets add all of the segments ot the database.

# %%
for i in range(len(route2_xy2)):
    # first test to see if it already exists
    fra_id = route2_xy2.iloc[i]['fraarcid']
    response = requests.get(URL4+str(fra_id), auth=TokenAuth(token))
    # if (response.status_code == 204):
    create_row(route2_xy2.iloc[i], route2_ll2.iloc[i], [5], URL2, token)
    # print(route2_xy2.iloc[i][['fraarcid','frfranode', 'tofranode','net','miles']])

# %% [markdown]
# The next step to saving a route is to include an  ordered list of nodes used make the route.

# %%
len(route2_xy2)
# Out:
# 284

# %%
URL5 = URL + "/api/route/add/"

# %%
URL6 = URL + "/api/yard/all/"

# %%
response = requests.get(URL6, auth=TokenAuth(token))

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'results': [{'id': 1, 'name': 'Landers Yard'},
#   {'id': 2, 'name': 'Rickenbacker'}]}

# %%
URL7 = URL + "/api/yard/"

# %%
response = requests.get(URL7+'1', auth=TokenAuth(token))

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'results': {'id': 1,
#   'code': 'LND',
#   'name': 'Landers Yard',
#   'city': 'Chicago',
#   'state': 'IL',
#   'location': 414008,
#   'owner': 7}}

# %%
route = {
    'origin': 1,
    'destination': 2,
    'owner': 5,
    'path': route2
}

# %%
res = requests.post(URL5, data=route, auth=TokenAuth(token))

# %%
res.json()
# Out:
# {'results': 1}

# %%
URL8 = URL + "/api/route/detail/"

# %%
response = requests.get(URL8+'1', auth=TokenAuth(token))

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'results': 1}

# %% [raw]
# for i in range(len(route2_xy)):
#     # first test to see if it already exists
#     fra_id = route2_xy.iloc[i]['FRAARCID']
#     response = requests.get(URL4+str(fra_id), auth=TokenAuth(token))
#     print(fra_id, response.status_code)

# %% [markdown]
# This will delete a recond from the Lines table - there happened to be a main and siding line with the same from and to nodes - this made for odd results

# %%
response = requests.get(URL+'/api/line/delete/417543', auth=TokenAuth(token))

# %%
response
# Out:
# <Response [200]>
