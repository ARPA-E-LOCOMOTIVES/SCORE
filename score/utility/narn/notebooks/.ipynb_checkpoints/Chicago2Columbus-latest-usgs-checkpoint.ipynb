# %% [markdown]
# # Chicago to Columbus NS
# This notebook selects the route from the Landers Intermodal yard in Chicago IL to the Rickenbacker Intermodal yard in Columbus OH.

# %%
import geopandas as gpd
import networkx as nx
from shapely import geometry, ops
import numpy as np
import matplotlib.pyplot as plt
import requests
import pandas as pd
import folium
import time
from requests.auth import AuthBase
import os
from scipy.spatial import distance

# %%
URL ="http://score-web-1:8000"
URL1 = URL+"/api-token-auth/"
payload = {'username':'locomotives', 'password':'locomotives'}
URL2 = URL+"/api/line/add/"
URL3 = URL+'/api/railroad/'
URL4 = URL + "/api/line/"
URL5 = URL + "/api/route/add/"
URL6 = URL + "/api/yard/all/"
URL7 = URL + "/api/yard/"
URL8 = URL + "/api/route/detail/"
URL9 = URL + "/api/route/elevations/update/"
URL10 = URL + "/api/yard/add/"

# %%
t = requests.post(URL1, data=payload )
token = t.json().get('token')
print(token)
# Out:
# de3e77241f347a6b85aa9e49bd12bdd361342e87

# %%
class TokenAuth(AuthBase):
    """ Implements a custom authentication scheme. """

    def __init__(self, token):
        self.token = token

    def __call__(self, r):
        """ Attach an API token to a custom auth header. """
        r.headers['Authorization'] = "Token " + f'{self.token}'
        return r

# %%
r = requests.get(URL3, auth=TokenAuth(token))
railroads=r.json()['results']
railroads
# Out:
# [{'id': 1, 'code': 'BNSF', 'name': 'Burlington Northern and Santa Fe'},
#  {'id': 2, 'code': 'CN', 'name': 'Canadian National Railway'},
#  {'id': 3, 'code': 'CP', 'name': 'Canadian Pacific Railway'},
#  {'id': 4, 'code': 'CSXT', 'name': 'CSX Transportation'},
#  {'id': 5, 'code': 'NS', 'name': 'Norfolk Southern Railway'},
#  {'id': 6, 'code': 'KCS', 'name': 'Kansas City Southern Railway'},
#  {'id': 7, 'code': 'UP', 'name': 'Union Pacific'}]

# %%
response = requests.get(URL6, auth=TokenAuth(token))
yards = response.json()['results']
yards
# Out:
# [{'id': 1, 'name': 'Landers Yard'}, {'id': 2, 'name': 'Rickenbacker'}]

# %%
dataYard = {'code': 'CXT',
 'name': 'Croxton',
 'city': 'Croxton',
 'state': 'NJ',
 'location': 489565,
 'owner': 5}
response = requests.post(URL10, data=dataYard, auth=TokenAuth(token))

# %%
response = requests.get(URL7+'1', auth=TokenAuth(token))
start = response.json()['results']
start
# Out:
# {'id': 1,
#  'code': 'LND',
#  'name': 'Landers Yard',
#  'city': 'Chicago',
#  'state': 'IL',
#  'location': 414008,
#  'owner': 7}

# %%
response = requests.get(URL7+'2', auth=TokenAuth(token))
end = response.json()['results']
end
# Out:
# {'id': 2,
#  'code': 'RIC',
#  'name': 'Rickenbacker',
#  'city': 'Columus',
#  'state': 'OH',
#  'location': 442152,
#  'owner': 5}

# %%
data = gpd.read_file("North_American_Rail_Network_Lines.geojson")

# %% [markdown]
# The column used to all be capitalized, now they are lower case.

# %%
data.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 data.columns
#
# AttributeError: 'dict' object has no attribute 'columns'

# %%
ns_data = data[data[['rrowner1', 'rrowner2', 'rrowner3', 'trkrghts1', 'trkrghts2', 'trkrghts3', 'trkrghts4', 'trkrghts5', 'trkrghts6', 'trkrghts7', 'trkrghts8', 'trkrghts9']].isin(['NS']).any(axis=1)]
#ns_data = data

# %% [markdown]
# ## Determine the shortest route
# We use the networkx library to determine the "optimal" route between two nodes on a graph. For this optimization, the graph consists of all nodes and "edges" or lines for which NOrfolk Southern has owns or has rights. This was determiend above.

# %%
from_nodes = list(ns_data.frfranode)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 from_nodes = list(ns_data.frfranode)
#
# NameError: name 'ns_data' is not defined

# %%
to_nodes = list(ns_data.tofranode)

# %% [markdown]
# The nodes in the graph is a union of all of the to and from nodes in the dataset.

# %%
all_nodes = list(set(from_nodes) | set(to_nodes))

# %% [markdown]
# Out of curiosity, how many are there? Quite a few, but this graph is not highly interconnected.

# %%
len(all_nodes)
# Out:
# 29689

# %% [markdown]
# The next step is to actually create a graph.

# %%
G=nx.Graph()

# %%
G.add_nodes_from(all_nodes)

# %% [markdown]
# We need to add the edges between the nodes and give them a weighting of the distane between the nodes - this will result in the shortest route.

# %%
edges = ns_data[['frfranode','tofranode', 'miles']].to_records(index=False).tolist()

# %%
G.add_weighted_edges_from(edges)

# %%
G.remove_node(442113)
route = nx.astar_path(G, 414094, 442152)

# %%
route_data = ns_data[(ns_data['frfranode'].isin(route) & ns_data['tofranode'].isin(route))]

# %%
fig = folium.Figure(height=600)
map = folium.Map(location=[40.75, -85.0], zoom_start=10,tile=None)
folium.TileLayer(tiles='http://{s}.tiles.openrailwaymap.org/standard/{z}/{x}/{y}.png', attr='OpenStreetMap attribution').add_to(map)
folium.TileLayer(tiles='http://{s}.google.com/vt/lyrs=s,h&x={x}&y={y}&z={z}', attr='Google Maps').add_to(map)
folium.GeoJson(route_data).add_to(map)
map.add_to(fig)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bf855b8540a2bd7c31905f758052f941 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bf855b8540a2bd7c31905f758052f941&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bf855b8540a2bd7c31905f758052f941 = L.map(
#                 &quot;map_bf855b8540a2bd7c31905f758052f941&quot;,
#                 {
#                     center: [40.75, -85.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_837ef3504d2b92ad0e226877e5b2fcb3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_837ef3504d2b92ad0e226877e5b2fcb3.addTo(map_bf855b8540a2bd7c31905f758052f941);
#
#
#             var tile_layer_60f3ccc0ada0862629d282bcf1946d6d = L.tileLayer(
#                 &quot;http://{s}.tiles.openrailwaymap.org/standard/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;OpenStreetMap attribution&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_60f3ccc0ada0862629d282bcf1946d6d.addTo(map_bf855b8540a2bd7c31905f758052f941);
#
#
#             var tile_layer_192d43cfe62398d00d83badb97e68fad = L.tileLayer(
#                 &quot;http://{s}.google.com/vt/lyrs=s,h\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Maps&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_192d43cfe62398d00d83badb97e68fad.addTo(map_bf855b8540a2bd7c31905f758052f941);
#
#
#
#         function geo_json_45e2085e279be9d2794ad5bced2e4325_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_45e2085e279be9d2794ad5bced2e4325 = L.geoJson(null, {
#                 onEachFeature: geo_json_45e2085e279be9d2794ad5bced2e4325_onEachFeature,
#
#         });
#
#         function geo_json_45e2085e279be9d2794ad5bced2e4325_add (data) {
#             geo_json_45e2085e279be9d2794ad5bced2e4325
#                 .addData(data);
#         }
#             geo_json_45e2085e279be9d2794ad5bced2e4325_add({&quot;bbox&quot;: [-87.68545129599994, 39.77872073900005, -82.84336316499997, 41.758096], &quot;features&quot;: [{&quot;bbox&quot;: [-82.93860829599998, 40.95596982700005, -82.93766674599993, 40.957631700000036], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-82.93766674599993, 40.957631700000036], [-82.93770057599994, 40.95757198700005], [-82.93770641099997, 40.95756169200007], [-82.93782598699994, 40.95735063200004], [-82.93836103699994, 40.956406247000075], [-82.93860829599998, 40.95596982700005]]], &quot;type&quot;: &quot;MultiLineString&quot;}, &quot;id&quot;: &quot;89304&quot;, &quot;properties&quot;: {&quot;branch&quot;: &quot;#N\\A&quot;, &quot;cntyfips&quot;: &quot;033&quot;, &quot;country&quot;: &quot;US&quot;, &quot;division&quot;: &quot;GREAT LAKES&quot;, &quot;fraarcid&quot;: 390281, &quot;fradistrct&quot;: 2, &quot;frfranode&quot;: 442333, &quot;km&quot;: 0.20085952, &quot;miles&quot;: 0.12480807, &quot;net&quot;: &quot;M&quot;, &quot;objectid&quot;: 89855, &quot;passngr&quot;: null, &quot;rrowner1&quot;: &quot;NS&quot;, &quot;rrowner2&quot;: null, &quot;rrowner3&quot;: null, &quot;shape_Length&quot;: 0.0019100623736844138, &quot;stateab&quot;: &quot;OH&quot;, &quot;stcntyfips&quot;: &quot;39033&quot;, &quot;stfips&quot;: &quot;39&quot;, &quot;stracnet&quot;: null, &quot;subdiv&quot;: &quot;SANDUSKY DISTRICT&quot;, &quot;timezone&quot;: &quot;E&quot;, &quot;tofranode&quot;: 442327, &quot;tracks&quot;: 1.0, &quot;trkrghts1&quot;: &quot;WE&quot;, &quot;trkrghts2&quot;: null, &quot;trkrghts3&quot;: null, &quot;trkrghts4&quot;: null, &quot;trkrghts5&quot;: null, &quot;trkrghts6&quot;: null, &quot;trkrghts7&quot;: null, &quot;trkrghts8&quot;: null, &quot;trkrghts9&quot;: null, &quot;yardname&quot;: null}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-83.97868470199995, 41.10489566100006, -83.97816077499994, 41.104906534000065], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-83.97868470199995, 41.10489566100006], [-83.97862477899997, 41.10489690600008], [-83.97816077499994, 41.104906534000065]]], &quot;type&quot;: &quot;MultiLineString&quot;}, &quot;id&quot;: &quot;89335&quot;, &quot;properties&quot;: {&quot;branch&quot;: &quot;#N\\A&quot;, &quot;cntyfips&quot;: &quot;137&quot;, &quot;country&quot;: &quot;US&quot;, &quot;division&quot;: &quot;GREAT LAKES&quot;, &quot;fraarcid&quot;: 390312, &quot;fradistrct&quot;: 2, &quot;frfranode&quot;: 435807, &quot;km&quot;: 0.0440273, &quot;miles&quot;: 0.02735724, &quot;net&quot;: &quot;M&quot;, &quot;objectid&quot;: 89886, &quot;passngr&quot;: nul

# %% [markdown]
# This results is a route where you need to turn around in Bucyrus. We can create a udpated grap
# h that removes a node in the "u-turn" part of the track (442,113) from the graph and have it solve again.

# %% [markdown]
# This route looks good, we can now move onto the next phase, simplification and segmentation. There are 3238 cooridnataes in this route. This can be reduced with simplify. Before we simplify, we need to convert the coordinate reference system to be in meters.

# %%
route_data = route_data.to_crs(3857)
simple_route = route_data.simplify(1, preserve_topology=False)
simple_route = simple_route.to_crs(4326)

# %%
fig = folium.Figure(height=600)
map = folium.Map(location=[40.75, -85.0], zoom_start=10,tile=None)
folium.TileLayer(tiles='http://{s}.tiles.openrailwaymap.org/standard/{z}/{x}/{y}.png', attr='OpenStreetMap attribution').add_to(map)
folium.TileLayer(tiles='http://{s}.google.com/vt/lyrs=s,h&x={x}&y={y}&z={z}', attr='Google Maps').add_to(map)
folium.GeoJson(simple_route).add_to(map)
map.add_to(fig)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_540b00256760b44d74743ab531755171 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_540b00256760b44d74743ab531755171&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_540b00256760b44d74743ab531755171 = L.map(
#                 &quot;map_540b00256760b44d74743ab531755171&quot;,
#                 {
#                     center: [40.75, -85.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f30c731ed5920b177554802ef6fb0bfd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f30c731ed5920b177554802ef6fb0bfd.addTo(map_540b00256760b44d74743ab531755171);
#
#
#             var tile_layer_7164f92ff525fa751ec6646e0593c50f = L.tileLayer(
#                 &quot;http://{s}.tiles.openrailwaymap.org/standard/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;OpenStreetMap attribution&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7164f92ff525fa751ec6646e0593c50f.addTo(map_540b00256760b44d74743ab531755171);
#
#
#             var tile_layer_a88ed591c0456184290f481b8509c800 = L.tileLayer(
#                 &quot;http://{s}.google.com/vt/lyrs=s,h\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Maps&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a88ed591c0456184290f481b8509c800.addTo(map_540b00256760b44d74743ab531755171);
#
#
#
#         function geo_json_1e362e5f550d1c8134b2d6d91ab73551_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_1e362e5f550d1c8134b2d6d91ab73551 = L.geoJson(null, {
#                 onEachFeature: geo_json_1e362e5f550d1c8134b2d6d91ab73551_onEachFeature,
#
#         });
#
#         function geo_json_1e362e5f550d1c8134b2d6d91ab73551_add (data) {
#             geo_json_1e362e5f550d1c8134b2d6d91ab73551
#                 .addData(data);
#         }
#             geo_json_1e362e5f550d1c8134b2d6d91ab73551_add({&quot;bbox&quot;: [-87.68545129599993, 39.77872073900004, -82.84336316499997, 41.75809600000001], &quot;features&quot;: [{&quot;bbox&quot;: [-82.93860829599997, 40.95596982700005, -82.93766674599993, 40.957631700000036], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-82.93766674599993, 40.957631700000036], [-82.93860829599997, 40.95596982700005]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;89304&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-83.97868470199995, 41.10489566100006, -83.97816077499994, 41.104906534000065], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-83.97868470199995, 41.10489566100006], [-83.97816077499994, 41.104906534000065]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;89335&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-83.97883815199997, 41.10489247800006, -83.97868470199995, 41.10489566100006], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-83.97883815199997, 41.10489247800006], [-83.97868470199995, 41.10489566100006]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;89336&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-82.94494992299997, 40.89837532200005, -82.93860829599997, 40.95596982700005], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-82.94491226299994, 40.89837532200005], [-82.94494992299997, 40.90428024100003], [-82.94493397199993, 40.90571553400008], [-82.94484265199996, 40.90648797800003], [-82.94466181399996, 40.907201816000054], [-82.94443338499995, 40.907839513000056], [-82.94409074299995, 40.90849624400005], [-82.94379430099995, 40.908962200000076], [-82.94140481199996, 40.91199636400005], [-82.94082622199993, 40.91295326300008], [-82.94037970199996, 40.914306391000025], [-82.94021436999998, 40.91567627800003], [-82.94012449999995, 40.921356200000055], [-82.94008373099996, 40.92814107400005], [-82.93996637299995, 40.935811243000046], [-82.93988370699996, 40.94377075500006], [-82.93981285099994, 40.94694747200003], [-82.93980104199994, 40.94822288400007], [-82.93982700099997, 40.950119], [-82.93978867799994, 40.951907131000034], [-82.93975060699994, 40.95250675400007], [-82.93967446399995, 40.95323962900005], [-82.93953169699995, 40.95394394900006], [-82.93934133999993, 40.954572127000056], [-82.93907483899993, 40.95522885700006], [-82.93860829599997, 40.95596982700005]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;89649&quot;, &quot;properties&

# %% [markdown]
# There does not appear to be any significnat difference. How many points do we currently have?

# %%
coords = simple_route.geometry.get_coordinates()

# %%
len(coords)
# Out:
# 1395

# %% [markdown]
# To better support the estimation of gradient (and may also assist in curvature), we should segmentize the data to have a maximum distance between points.

# %%
simple_route = simple_route.to_crs(3857)
simple2_route = simple_route.segmentize(max_segment_length=100)
simple2_route = simple2_route.to_crs(4326)
len(simple2_route.geometry.get_coordinates())
# Out:
# 9319

# %% [markdown]
# big oof here, setting max segemetn length to 100 meteres give us 9351 coordinates - too many fo rthis short route.

# %%
simple_route = simple_route.to_crs(3857)
simple2_route = simple_route.segmentize(max_segment_length=200)
simple2_route = simple2_route.to_crs(4326)
len(simple2_route.geometry.get_coordinates())
# Out:
# 5104

# %% [markdown]
# Doubling this distance to 200 meters reduces to 5124 coordinates. We can try to get the necessary altitudes at this point. This is a relative long process of querrying. The data in the dataframe consists of a number of line segments. In this case there are 284

# %%
len(simple2_route)
# Out:
# 281

# %% [markdown]
# We will take the geometry of each row in the data frame and create a few new data elements or columns. The first will be to create the 'xyz' data.
# The geometric data uses the 4326 crs, or lat-long system. Using this information we can query the UGS website to get the altitude. This data will get stores in a "z" column fo rnow and then after converting the the 3857 crs, we can get distances in meters to make the xyz column.

# %% [markdown]
# Instead, lets do some piece work to better understand what we have. The first thing to notice is the list is not ordered from beginning to end. All of the segments are there, but they were taken "randomly" - by order of their OBJECTID.

# %%
row = route_data.iloc[0]

# %% [markdown]
# route2 holds the ordered list of nodes. The prior system of selecting the lines that have the nodes resulted in the "randomness" of the results. Instead, we nee to create a new data frame incrementally.

# %%
route2[0]
# Out:
# 414008

# %%
route2[1]
# Out:
# 414159

# %% [markdown]
# The odd thing here is that we "started" with the line above, but it is not actually part of the route.

# %%
def curve(p1, p2, p3):
    v1=p2-p1
    v2=p3-p2
    v3=p1-p3
    d1=np.linalg.norm(v1)
    d2=np.linalg.norm(v2)
    d3=np.linalg.norm(v3)
    num = 1746.375*2*np.linalg.norm(np.cross(v1,v2))
    d = num/(d1*d2*d3)
    if d<0.01:
        d=0.0
    return d

# %%
route_data.crs
# Out:
# <Projected CRS: EPSG:3857>
# Name: WGS 84 / Pseudo-Mercator
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: World between 85.06°S and 85.06°N.
# - bounds: (-180.0, -85.06, 180.0, 85.06)
# Coordinate Operation:
# - name: Popular Visualisation Pseudo-Mercator
# - method: Popular Visualisation Pseudo Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
route2_xy = route_data.copy()

# %%
route2_ll = route_data.to_crs(4326)

# %% [markdown]
# let's make a function to add each entry in a dataframe. It will take in a row, get the elevations, calculate gradients and curvatures and put the data into the database.

# %%
API_KEY=

# %% [markdown]
# Lets modify the above to get all of the elevations in a single call.

# %%
def get_alt(lat, lng):


    # ARL Machine Approach
    res = []
    for i in range(len(lng)):
        lt = lat[i]
        lg = lng[i]
        url = "https://epqs.nationalmap.gov/v1/json?x=" + str(lg) + "&y=" + str(lt) + "&units=Feet&wkid=4326&includeDate=False"
        response = requests.get(url)
        ele_m = response.json()['value']*0.3048
        res.append(ele_m)
        print(lg, lt, ele_m)
    
#    st = ""
    # print(lng)
#    for i in range(len(lng)):
#        st+=str(lat[i])+','+str(lng[i])+'|'
#    st=st[:-1]
#    url = "https://maps.googleapis.com/maps/api/elevation/json?locations=" + st + "&key=" + API_KEY
    # print(url)
#    response = requests.get(url)
    # result = response.json()['results']['elevation']
    # print(response.status)
    # print(response.json()['results'])
#    results = response.json()['results']
#    res = []
#    for rec in results:
#        res.append(rec['elevation'])
    # should put in a test for response status before returning an actual value
    return res

# %%
codes = [d['code'] for d in railroads]
codes
# Out:
# ['BNSF', 'CN', 'CP', 'CSXT', 'NS', 'KCS', 'UP']

# %%
def create_row(rowxy, rowll, rights, url, token=None):
    rights = []
    for code in codes:
        if rowxy[['rrowner1', 'rrowner2', 'rrowner3', 'trkrghts1', 'trkrghts2', 'trkrghts3', 'trkrghts4', 'trkrghts5', 'trkrghts6', 'trkrghts7', 'trkrghts8', 'trkrghts9']].isin([code]).any():
            rights.append(code)
    p = np.array(rowxy.geometry.coords)
    pxy = p[:,0:2]
    # we want the interpoint distance between the points - the offset of 1, diagonal of the cdist matrix
    dist = np.diagonal(distance.cdist(pxy, pxy), offset=1)
    lng,lat = rowll.geometry.xy
    ele=get_alt(lat, lng)
    lnglat = np.array(rowll.geometry.coords)
    dele = np.diff(ele)
    gradient = np.divide(dele, dist)
    curvature=[]
    if (len(pxy)>2):
        for i in range(len(pxy)-2):
            curvature.append(curve(pxy[i],pxy[i+1],pxy[i+2]))
        curvature.append(curvature[-1])
    else:
        curvature = [0.0]
    line = {
        "fra_id" : rowxy['fraarcid'],
        "from_node" : rowxy['frfranode'],
        "to_node" : rowxy['tofranode'],
        "length" :dist.sum(),
        "rights" : rights,
        "net": rowxy['net'],
        "xy": pxy.tolist(),
        "elevation": ele,
        "lnglat": lnglat.tolist(),
        "gradient": gradient.tolist(),
        "curvature": curvature,
        "distance":dist.tolist()
    }
    requests.post(url, data=line, auth=TokenAuth(token))
    print(line['fra_id'])

# %% [markdown]
# we need to explode the multiliestrings that are being used now to be linestrings

# %%
route2_xy.geometry=simple2_route.to_crs(3857)
route2_xy2 = route2_xy.explode(index_parts=True)

# %%
np.array(route2_xy2.iloc[0].geometry.coords)
# Out:
# array([[-9232578.82974693,  5006094.35639577],
#        [-9232631.23618021,  5005971.8736939 ],
#        [-9232683.64261349,  5005849.39099204]])

# %% [markdown]
# Test to add one row

# %%
route2_ll.geometry=simple2_route
route2_ll2 = route2_ll.explode(index_parts=True)
np.array(route2_ll2.iloc[0].geometry.coords)
# Out:
# array([[-82.93766675,  40.9576317 ],
#        [-82.93813752,  40.95680077],
#        [-82.9386083 ,  40.95596983]])

# %%
create_row(route2_xy2.iloc[0], route2_ll2.iloc[0], [5], URL2, token)
# Out:
# -82.93766674599993 40.957631700000036 987.8234979128443
# -84.67668192434371 41.08256008465719 226.48807487461815
# -84.67490438856247 41.08262811517525 226.5446544664287
# -84.67312685278121 41.082696145622876 226.59319267598192
# -84.67134931699997 41.08276417600007 226.6755443626172
# 519032
# -83.54336782699993 41.11204882600003 245.4827349064473
# -83.54157926785707 41.11207269562785 245.6669084963408
# -83.53979070871421 41.11209656524702 246.2093889827002
# -83.53800214957135 41.11212043485751 246.19423700421535
# -83.5362135904285 41.1121443044593 245.93167901281348
# -83.53442503128565 41.11216817405242 245.67836784670752
# -83.5326364721428 41.11219204363687 245.62294792293406
# -83.53084791299993 41.11221591321264 245.52014945864454
# -83.52905935385708 41.11223978277972 245.58638786376414
# -83.52727079471423 41.112263652338136 245.58124565159963
# -83.52548223557136 41.11228752188785 245.77498650279932
# -83.52369367642852 41.112311391428904 245.86188530858007
# -83.52190511728566 41.112335260961274 245.8520891662666
# -83.5201165581428 41.11235913048497 245.56797050417484
# -83.51832799899995 41.11238299999999 245.1105577705376
# -83.51670599999997 41.112409 244.63684864837893
# -83.51575199999998 41.11245400100007 244.49134083172265
# -83.514704 41.11254999999999 244.3432542789839
# -83.51382399899995 41.112671 244.40219898287015
# -83.512847 41.112847 244.5781480855005
# -83.51188199999997 41.11306599999999 244.76779958056935
# -83.51091000099996 41.113336999000055 244.89380666460156
# -83.51005299899998 41.113621 245.0383074022256
# -83.50914599899994 41.113969 245.2291796003335
# -83.508353 41.11431700000001 245.57212089530765
# -83.507591306 41.11468390402537 245.8932421215835
# -83.50682961199999 41.115050806000056 246.13835931642728
# 523795
# -82.95709214399994 39.792644867000035 219.46753631996094
# -82.95703471399997 39.79340715200004 219.5585549998735
# 530848
# -83.11891419699997 41.24757382400003 208.37503718600098
# -83.11846769699994 41.24766065400007 207.86325738362405
# -83.11796127399998 41.24790180700006 207.20291800749314
# -83.11764777399998 41.24798621200005 206.8934850145913
# -83.11646612199998 41.248010327504495 206.80777639284867
# -83.11528446999995 41.248034443000044 206.76965993662893
# -83.11472981699993 41.247805346000064 207.86803338477688
# -83.11409399599995 41.247749972000065 208.43662165997168
# 530850
# -82.84678966599995 41.255880452000035 237.98944853366214
# -82.84711089899994 41.25541243100002 238.22618865323778
# 530853

# %% [markdown]
# The next step to saving a route is to include an  ordered list of nodes used make the route.

# %%
len(route2_xy2)
# Out:
# 281

# %% [markdown]
# Get the details on a specific yard.

# %%
response = requests.get(URL7+'1', auth=TokenAuth(token))

# %%
response.json()
# Out:
# {'results': {'id': 1,
#   'code': 'LND',
#   'name': 'Landers Yard',
#   'city': 'Chicago',
#   'state': 'IL',
#   'location': 414008,
#   'owner': 7}}

# %% [markdown]
# These next few lines will save the route to the database.

# %%
routeJson = {
    'origin': 1,
    'destination': 2,
    'owner': 5,
    'path': route
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 5
#       1 routeJson = {
#       2     'origin': 1,
#       3     'destination': 2,
#       4     'owner': 5,
# ----> 5     'path': route
#       6 }
#
# NameError: name 'route' is not defined

# %%
res = requests.post(URL5, data=routeJson, auth=TokenAuth(token))
print(res)
# Out:
# <Response [200]>

# %% [markdown]
# This will get the route data from the database.

# %%
response = requests.get(URL8+'1', auth=TokenAuth(token))

# %%
response.status_code
# Out:
# 200

# %%
segments=response.json()['results']['segments']

# %%
start_elevation = response.json()['results']['start_elevation']
print(start_elevation)
# Out:
# 185.97534774821096

# %% [markdown]
# We can push the data into a Pandas dataframe easily.

# %%
seg_df = pd.DataFrame(segments)

# %%
seg_df
# Out:
#           length   degrees  gradient       distance   elevation  order
# 0     176.822739  0.000000  0.000638     176.822739  187.726089      0
# 1     176.822739  0.000000 -0.004461     353.645478  186.937271      1
# 2     176.822739  0.000000 -0.002964     530.468217  186.413239      2
# 3     176.822739  1.443388 -0.002603     707.290956  185.952957      3
# 4      85.229896  2.151147  0.009883     792.520852  186.795288      4
# ...          ...       ...       ...            ...         ...    ...
# 4567  183.679731  0.000000  0.000555  807808.868398  219.292130   4567
# 4568  183.679731  0.000000 -0.000462  807992.548129  219.394073   4568
# 4569  183.679731  0.000000 -0.000129  808176.227860  219.309235   4569
# 4570  183.679731  0.000000 -0.000771  808359.907591  219.285629   4570
# 4571  183.679731  0.000000 -0.000607  808543.587322  219.143982   4571
#
# [4572 rows x 6 columns]

# %%
seg_df.plot(x="distance", y="elevation")
# Out:
# <Axes: xlabel='distance'>

# %% [markdown]
# We have a relatively noisy route. Lets try some filtering to smooth things out.

# %%
seg_df.plot(x="distance", y="gradient")
# Out:
# <Axes: xlabel='distance'>

# %%
def savgol_nonuniform(x, y, window_length, polyorder, deriv=0):
    """
    Savitzky-Golay smoothing 1D filter

    :param x:
    :param y:
    :param window_length: the smoothing sample, e.g. window_length=2 for smoothing over 5 points
    :param polyorder: the degree of the local polynomial fit, e.g. polyorder=2 for a parabolic fit
    :param deriv: The order of the derivative to compute. This must be a nonnegative integer.
            The default is 0, which means to filter the data without differentiating.
    :return:
    """
    if type(x) is not np.array:
        x = np.array(x)
    if type(y) is not np.array:
        y = np.array(y)

    n = int((window_length - 1) / 2)

    if x.shape != y.shape:
        raise RuntimeError("x and y arrays are of different shape")
    if x.shape[0] < window_length:
        raise RuntimeError("not enough data to start the smoothing process")
    if 2 * n + 1 <= polyorder + 1:
        raise RuntimeError("need at least deg+1 points to make the polynomial")

    # smooth start and end data
    ysm = np.zeros(y.shape)
    for i in range(n):
        j = y.shape[0] - i - 1
        if deriv == 0:
            ysm[i] = y[i]
            ysm[j] = y[j]
        if deriv == 1:
            ysm[i] = (y[i] - y[i - 1]) / (x[i] - x[i - 1])
            ysm[j] = (y[j] - y[j - 1]) / (x[j] - x[j - 1])
        if deriv == 2:
            ysm[i] = (((y[i] - y[i - 1]) / (x[i] - x[i - 1])) - ((y[i - 1] - y[i - 2]) / (x[i - 1] - x[i - 2]))) / \
                     (x[i] - x[i - 1])
            ysm[j] = (((y[j] - y[j - 1]) / (x[j] - x[j - 1])) - ((y[j - 1] - y[j - 2]) / (x[j - 1] - x[j - 2]))) / \
                     (x[j] - x[j - 1])
        if deriv >= 3:
            raise NotImplementedError("derivatives >= 3 not implemented")

    m = 2 * n + 1  # the size of the filter window
    o = polyorder + 1  # the smoothing order
    A = np.zeros((m, o))  # A matrix
    t = np.zeros(m)
    # start smoothing
    for i in range(n, x.shape[0] - n):
        for j in range(m):
            t[j] = x[i + j - n] - x[i]
        for j in range(m):
            r = 1.0
            for k in range(o):
                A[j, k] = r
                r *= t[j]
        tA = A.transpose()  # A transposed
        tAA = np.matmul(tA, A)  # make tA.A
        tAA = np.linalg.inv(tAA)  # make (tA.A)-¹ in place
        tAAtA = np.matmul(tAA, tA)  # make (tA.A)-¹.tA

        # compute the polynomial's value at the center of the sample
        ysm[i] = 0.0
        for j in range(m):
            ysm[i] += tAAtA[deriv, j] * y[i + j - n]

    return ysm

# %%
x=np.insert(np.array(seg_df['distance']),0,0.0,axis=0)

# %%
x
# Out:
# array([0.00000000e+00, 3.51240975e+01, 7.09818714e+01, ...,
#        8.05967036e+05, 8.06150716e+05, 8.06334395e+05])

# %%
y=np.insert(np.array(seg_df['elevation']),0, start_elevation, axis=0)

# %%
start_elevation
# Out:
# 185.97534774821096

# %%
len(x)
# Out:
# 4556

# %%
len(y)
# Out:
# 4556

# %% [markdown]
# Let's use a relatively large window size of 51 and a 3rd order polynomial.

# %%
new_elevations = savgol_nonuniform(x,y, 51, 3, 0)
seg_df['new_elevations']=new_elevations[1:]

# %%
plt.figure(figsize=(16, 8))
seg_df.plot(x="distance", y=["elevation","new_elevations"])
# Out:
# <Axes: xlabel='distance'>

# %% [markdown]
# Next step is to go through and modify the gradients to go with the new elevations. The first step is tp calcuate the deltas between elevations.

# %%
dele = np.diff(new_elevations)
len(dele)
# Out:
# 4555

# %%
delx = np.diff(x)
len(delx)
# Out:
# 4555

# %% [markdown]
# just a quick check to see if things are abot the same as before

# %%
temp=delx-np.array(seg_df['length'])
temp.sum()
# Out:
# -3.4382967584178914e-09

# %%
grads = np.divide(dele, delx)

# %%
grads.max()
# Out:
# 0.0138101540856842

# %%
seg_df.gradient=grads

# %%
seg_df.plot(x="distance", y="new_elevations")
# Out:
# <Axes: xlabel='distance'>

# %%
seg_df.plot(x="distance", y="gradient")
# Out:
# <Axes: xlabel='distance'>

# %% [markdown]
# This seems to be a reasonable balance for smoothing without going to using other methods. The primary desire is to capture the changes in elevations to include this impact on sizing of batteries.

# %%
data={
    'route':1, 
    'elevations': new_elevations,
    'gradients': list(seg_df['gradient'])
}
token
# Out:
# 'de3e77241f347a6b85aa9e49bd12bdd361342e87'

# %% [markdown]
# lets try to update the elevations.

# %% [markdown]
# This seems to work now. The next step is to verify that it did work.

# %%
res = requests.post(URL11, data=data, auth=TokenAuth(token))

# %%
response = requests.get(URL8+'1', auth=TokenAuth(token))
print(response.status_code)
segments=response.json()['results']['segments']
start_elevation = response.json()['results']['start_elevation']
seg_df2 = pd.DataFrame(segments)
# Out:
# 200

# %%
seg_df2.plot(x="distance", y="elevation")
# Out:
# <Axes: xlabel='distance'>

# %%
seg_df2.plot(x="distance", y="gradient")
# Out:
# <Axes: xlabel='distance'>

# %% [markdown]
# This all seems to work.
