# %% [markdown]
# # Chicago to Cleveland
# This notebook selects the route from the 47th Street Intermodal yard in Chicago IL to the Maple Heights Intermodal yard in Cleveland OH.

# %%
import geopandas as gpd
import networkx as nx
from shapely import geometry, ops
import numpy as np
import matplotlib.pyplot as plt
import requests
import pandas as pd
import folium
import time
from requests.auth import AuthBase
import os
from scipy.spatial import distance

# %%
URL ="http://score-web-1:8000"
URL1 = URL+"/api-token-auth/"
payload = {'username':'locomotives', 'password':'locomotives'}
URL2 = URL+"/api/line/add/"
URL3 = URL+'/api/railroad/'
URL4 = URL + "/api/line/"
URL5 = URL + "/api/route/add/"
URL6 = URL + "/api/yard/all/"
URL7 = URL + "/api/yard/"
URL8 = URL + "/api/route/detail/"
URL9 = URL + "/api/route/elevations/update/"
URL10 = URL + "/api/yard/add/"

# %%
t = requests.post(URL1, data=payload )
token = t.json().get('token')

# %%
class TokenAuth(AuthBase):
    """ Implements a custom authentication scheme. """

    def __init__(self, token):
        self.token = token

    def __call__(self, r):
        """ Attach an API token to a custom auth header. """
        r.headers['Authorization'] = "Token " + f'{self.token}'
        return r

# %% [markdown]
# Lets do a  quick test to make sure we can commmunicate with the server and grab the list of railroads.

# %%
r = requests.get(URL3, auth=TokenAuth(token))
railroads=r.json()['results']
railroads
# Out:
# [{'id': 1, 'code': 'BNSF', 'name': 'Burlington Northern and Santa Fe'},
#  {'id': 2, 'code': 'CN', 'name': 'Canadian National Railway'},
#  {'id': 3, 'code': 'CP', 'name': 'Canadian Pacific Railway'},
#  {'id': 4, 'code': 'CSXT', 'name': 'CSX Transportation'},
#  {'id': 5, 'code': 'NS', 'name': 'Norfolk Southern Railway'},
#  {'id': 6, 'code': 'KCS', 'name': 'Kansas City Southern Railway'},
#  {'id': 7, 'code': 'UP', 'name': 'Union Pacific'}]

# %% [markdown]
# When defining a route, we need a starting and and ending location. These typically occur in railraod yards. We can grab the list of available yards from the server.

# %%
response = requests.get(URL6, auth=TokenAuth(token))
yards = response.json()['results']
yards
# Out:
# [{'id': 2, 'name': 'Rickenbacker'},
#  {'id': 4, 'name': 'Norfolk'},
#  {'id': 3, 'name': 'Croxton'},
#  {'id': 6, 'name': 'Savannah'},
#  {'id': 7, 'name': 'Macon'},
#  {'id': 8, 'name': 'Tyrone'},
#  {'id': 9, 'name': 'State College'},
#  {'id': 5, 'name': 'Suffolk'},
#  {'id': 10, 'name': 'Croxton'},
#  {'id': 1, 'name': 'Landers Yard'},
#  {'id': 11, 'name': 'Bethlehem Intermodal'},
#  {'id': 12, 'name': 'Rutherford Intermodal'},
#  {'id': 13, 'name': 'Pitcairn Intermodal'},
#  {'id': 14, 'name': 'Maple Heights Intermodal'},
#  {'id': 15, 'name': '47th Street Intermodal'}]

# %% [markdown]
# We want to start this route at the 47th Street yard.

# %%
response = requests.get(URL7+'15', auth=TokenAuth(token))
start = response.json()['results']
start
# Out:
# {'id': 15,
#  'code': 'C47',
#  'name': '47th Street Intermodal',
#  'city': 'Chicago',
#  'state': 'IL',
#  'location': 414720,
#  'owner': 5}

# %% [markdown]
# and end at the Maple Heights Yard in Cleveland

# %%
response = requests.get(URL7+'14', auth=TokenAuth(token))
end = response.json()['results']
end
# Out:
# {'id': 14,
#  'code': 'MPH',
#  'name': 'Maple Heights Intermodal',
#  'city': 'Cleveland',
#  'state': 'OH',
#  'location': 450869,
#  'owner': 5}

# %%
data = gpd.read_file("North_American_Rail_Network_Lines.geojson")
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /opt/conda/share/proj failed

# %%
ns_data = data[data[['rrowner1', 'rrowner2', 'rrowner3', 'trkrghts1', 'trkrghts2', 'trkrghts3', 'trkrghts4', 'trkrghts5', 'trkrghts6', 'trkrghts7', 'trkrghts8', 'trkrghts9']].isin(['NS']).any(axis=1)]
#ns_data = data

# %% [markdown]
# ## Determine the shortest route
# We use the networkx library to determine the "optimal" route between two nodes on a graph. For this optimization, the graph consists of all nodes and "edges" or lines for which NOrfolk Southern has owns or has rights. This was determiend above.

# %%
from_nodes = list(ns_data.frfranode)

# %%
to_nodes = list(ns_data.tofranode)

# %% [markdown]
# The nodes in the graph is a union of all of the to and from nodes in the dataset.

# %%
all_nodes = list(set(from_nodes) | set(to_nodes))

# %% [markdown]
# The next step is to actually create a graph.

# %%
G=nx.Graph()

# %%
G.add_nodes_from(all_nodes)

# %% [markdown]
# We need to add the edges between the nodes and give them a weighting of the distance between the nodes - this will result in the shortest route.

# %%
edges = ns_data[['frfranode','tofranode', 'miles']].to_records(index=False).tolist()

# %%
G.add_weighted_edges_from(edges)

# %%
route = nx.astar_path(G, start['location'], end['location'])

# %%
route_data = ns_data[(ns_data['frfranode'].isin(route) & ns_data['tofranode'].isin(route))]

# %%
fig = folium.Figure(height=600)
map = folium.Map(location=[40.75, -85.0], zoom_start=10,tile=None)
folium.TileLayer(tiles='http://{s}.tiles.openrailwaymap.org/standard/{z}/{x}/{y}.png', attr='OpenStreetMap attribution').add_to(map)
folium.TileLayer(tiles='http://{s}.google.com/vt/lyrs=s,h&x={x}&y={y}&z={z}', attr='Google Maps').add_to(map)
folium.GeoJson(route_data).add_to(map)
map.add_to(fig)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_da6fb1652d358cc52220b8664f99b904 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_da6fb1652d358cc52220b8664f99b904&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_da6fb1652d358cc52220b8664f99b904 = L.map(
#                 &quot;map_da6fb1652d358cc52220b8664f99b904&quot;,
#                 {
#                     center: [40.75, -85.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_19caca1de4b047d817f5cd0aef02edd7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_da6fb1652d358cc52220b8664f99b904);
#
#
#             var tile_layer_2936d4dfb2b8dab494db24c31805831c = L.tileLayer(
#                 &quot;http://{s}.tiles.openrailwaymap.org/standard/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;OpenStreetMap attribution&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_da6fb1652d358cc52220b8664f99b904);
#
#
#             var tile_layer_cae64113e331a8bb4e425244516575ae = L.tileLayer(
#                 &quot;http://{s}.google.com/vt/lyrs=s,h\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Maps&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_da6fb1652d358cc52220b8664f99b904);
#
#
#
#         function geo_json_cbd87debbae644f69b2b33162b6d062c_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_cbd87debbae644f69b2b33162b6d062c = L.geoJson(null, {
#                 onEachFeature: geo_json_cbd87debbae644f69b2b33162b6d062c_onEachFeature,
#
#         });
#
#         function geo_json_cbd87debbae644f69b2b33162b6d062c_add (data) {
#             geo_json_cbd87debbae644f69b2b33162b6d062c
#                 .addData(data)
#                 .addTo(map_da6fb1652d358cc52220b8664f99b904);
#         }
#             geo_json_cbd87debbae644f69b2b33162b6d062c_add({&quot;bbox&quot;: [-87.63579400099997, 41.36855846800006, -81.56900155799997, 41.809142], &quot;features&quot;: [{&quot;bbox&quot;: [-83.54735187999995, 41.633896039000035, -83.53606167699996, 41.63782553200008], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-83.53606167699996, 41.633896039000035], [-83.53614742999997, 41.63395753800006], [-83.53663524599995, 41.63430738100004], [-83.53663600499993, 41.63430792500003], [-83.53668419699994, 41.634342487000026], [-83.53670500499999, 41.634357409000074], [-83.53690159199994, 41.63449839300006], [-83.53693297599995, 41.63452090100003], [-83.53693302899995, 41.634520939000026], [-83.53782170699998, 41.63515826300005], [-83.53860456099994, 41.63571969600008], [-83.538651, 41.635753], [-83.539299, 41.636168], [-83.53939624099996, 41.636217816000055], [-83.540234, 41.636647], [-83.54024098899998, 41.636650029000066], [-83.540707, 41.636852], [-83.54080952699996, 41.636889444000076], [-83.54136004099996, 41.637090502000035], [-83.54139699899997, 41.63710399900003], [-83.54224385099997, 41.63734945200008], [-83.542401, 41.63739499900004], [-83.54323669899998, 41.63756530300003], [-83.54356400099994, 41.637632], [-83.54363053799995, 41.63763868700005], [-83.54396834499994, 41.63767263400007], [-83.54425729199994, 41.63770167300004], [-83.54438625199998, 41.63771463100005], [-83.54450748199997, 41.637726815000065], [-83.54453005199997, 41.63772908300007], [-83.544778, 41.637754], [-83.54500190899995, 41.63776022300004], [-83.54529099199993, 41.63776825700006], [-83.54648088999994, 41.637801326000044], [-83.54735187999995, 41.63782553200008]]], &quot;type&quot;: &quot;MultiLineString&quot;}, &quot;id&quot;: &quot;89317&quot;, &quot;properties&quot;: {&quot;branch&quot;: &quot;#N\\A&quot;, &quot;cntyfips&quot;: &quot;095&quot;, &quot;country&quot;: &quot;US&quot;, &quot;division&quot;: &quot;GREAT LAKES&quot;, &quot;fraarcid&quot;: 390294, &quot;fradistrct&quot;: 2, &quot;frfranode&quot;: 438129, &quot;km&quot;: 1.07999988, &quot;miles&quot;: 0.67107947, &quot;net&quot;: &quot;M&quot;, &quot;objectid&quot;: 89868, &quot;passngr&quot;: &quot;A&quot;, &quot;rrowner1&quot;: &quot;NS&quot;, &quot;rrowner2&quot;: null, &quot;rrowner3&quot;: null, &quot;shape_Length&quot;: 0.012283718838137704, &quot;stateab&quot;: &quot;OH&quot;, &quot;stcntyfips&quot;: &quot;39095&quot;, &quot;stfips&quot;: &quot;39&quot;, &quot;stracnet&quot;: &quot;S&quot;, &quot;subdiv&quot;: &quot;CHICAGO LINE&quot;, &quot;timezone&quot;: &quot;E&quot;, &quot;tofranode&quot;: 438029, &quot;tracks&quot;: 2.0, &quot;trkrghts1&q

# %% [markdown]
# This route takes us through Toledo. We want to route through Fort Wayne instead so remvoe a node from this route to help force it to go through Fort Wayne.

# %%
G.remove_node(437112)

# %%
route2 = nx.astar_path(G,start['location'], end['location'])

# %%
route2_data = ns_data[(ns_data['frfranode'].isin(route2) & ns_data['tofranode'].isin(route2))]

# %%
fig = folium.Figure(height=600)
map = folium.Map(location=[40.75, -85.0], zoom_start=10,tile=None)
folium.TileLayer(tiles='http://{s}.tiles.openrailwaymap.org/standard/{z}/{x}/{y}.png', attr='OpenStreetMap attribution').add_to(map)
folium.TileLayer(tiles='http://{s}.google.com/vt/lyrs=s,h&x={x}&y={y}&z={z}', attr='Google Maps').add_to(map)
folium.GeoJson(route2_data).add_to(map)
map.add_to(fig)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f266b341cbb1a51ecf65e94f5b9883a7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f266b341cbb1a51ecf65e94f5b9883a7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f266b341cbb1a51ecf65e94f5b9883a7 = L.map(
#                 &quot;map_f266b341cbb1a51ecf65e94f5b9883a7&quot;,
#                 {
#                     center: [40.75, -85.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d6b5b4026936fc45ccab77faf809cbf9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f266b341cbb1a51ecf65e94f5b9883a7);
#
#
#             var tile_layer_e0eb9cbaf2115e9494b8afaa4114a732 = L.tileLayer(
#                 &quot;http://{s}.tiles.openrailwaymap.org/standard/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;OpenStreetMap attribution&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f266b341cbb1a51ecf65e94f5b9883a7);
#
#
#             var tile_layer_10804b2bd05a0b706f72af5ef9a68b66 = L.tileLayer(
#                 &quot;http://{s}.google.com/vt/lyrs=s,h\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Maps&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f266b341cbb1a51ecf65e94f5b9883a7);
#
#
#
#         function geo_json_a014cc34880556a435489528fe841096_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_a014cc34880556a435489528fe841096 = L.geoJson(null, {
#                 onEachFeature: geo_json_a014cc34880556a435489528fe841096_onEachFeature,
#
#         });
#
#         function geo_json_a014cc34880556a435489528fe841096_add (data) {
#             geo_json_a014cc34880556a435489528fe841096
#                 .addData(data)
#                 .addTo(map_f266b341cbb1a51ecf65e94f5b9883a7);
#         }
#             geo_json_a014cc34880556a435489528fe841096_add({&quot;bbox&quot;: [-87.63579400099997, 41.071371001000045, -81.56900155799997, 41.809142], &quot;features&quot;: [{&quot;bbox&quot;: [-83.97868470199995, 41.10489566100006, -83.97816077499994, 41.104906534000065], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-83.97868470199995, 41.10489566100006], [-83.97862477899997, 41.10489690600008], [-83.97816077499994, 41.104906534000065]]], &quot;type&quot;: &quot;MultiLineString&quot;}, &quot;id&quot;: &quot;89335&quot;, &quot;properties&quot;: {&quot;branch&quot;: &quot;#N\\A&quot;, &quot;cntyfips&quot;: &quot;137&quot;, &quot;country&quot;: &quot;US&quot;, &quot;division&quot;: &quot;GREAT LAKES&quot;, &quot;fraarcid&quot;: 390312, &quot;fradistrct&quot;: 2, &quot;frfranode&quot;: 435807, &quot;km&quot;: 0.0440273, &quot;miles&quot;: 0.02735724, &quot;net&quot;: &quot;M&quot;, &quot;objectid&quot;: 89886, &quot;passngr&quot;: null, &quot;rrowner1&quot;: &quot;NS&quot;, &quot;rrowner2&quot;: null, &quot;rrowner3&quot;: null, &quot;shape_Length&quot;: 0.000524039810984336, &quot;stateab&quot;: &quot;OH&quot;, &quot;stcntyfips&quot;: &quot;39137&quot;, &quot;stfips&quot;: &quot;39&quot;, &quot;stracnet&quot;: null, &quot;subdiv&quot;: &quot;FOSTORIA DISTRICT&quot;, &quot;timezone&quot;: &quot;E&quot;, &quot;tofranode&quot;: 435809, &quot;tracks&quot;: 1.0, &quot;trkrghts1&quot;: null, &quot;trkrghts2&quot;: null, &quot;trkrghts3&quot;: null, &quot;trkrghts4&quot;: null, &quot;trkrghts5&quot;: null, &quot;trkrghts6&quot;: null, &quot;trkrghts7&quot;: null, &quot;trkrghts8&quot;: null, &quot;trkrghts9&quot;: null, &quot;yardname&quot;: null}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-83.97883815199998, 41.10489247800007, -83.97868470199995, 41.10489566100006], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-83.97883815199998, 41.10489247800007], [-83.97870662199995, 41.10489520600004], [-83.97870456299995, 41.10489525000003], [-83.97868470199995, 41.10489566100006]]], &quot;type&quot;: &quot;MultiLineString&quot;}, &quot;id&quot;: &quot;89336&quot;, &quot;properties&quot;: {&quot;branch&quot;: &quot;#N\\A&quot;, &quot;cntyfips&quot;: &quot;137&quot;, &quot;country&quot;: &quot;US&quot;, &quot;division&quot;: &quot;GREAT LAKES&quot;, &quot;fraarcid&quot;: 390313, &quot;fradistrct&quot;: 2, &quot;frfranode&quot;: 435805, &quot;km&quot;: 0.0128949, &quot;miles&quot;: 0.0080125, &quot;net&quot;: &quot;M&quot;, &quot;objectid&quot;: 89887, &quot;passngr&quot;: null, &quot;rrowner1&quot;: &quot;NS&quot;, &quot;rrowner2&quot;: null, &quot;rrowner3&quot;: null, &quot;shape_L

# %%
len(route2_data.geometry.get_coordinates())
# Out:
# 3219

# %% [markdown]
# This route looks good, we can now move onto the next phase, simplification and segmentation. There are 3219 cooridnataes in this route. This can be reduced with simplify. Before we simplify, we need to convert the coordinate reference system to be in meters.

# %%
route2_data = route2_data.to_crs(3857)
simple_route = route2_data.simplify(1, preserve_topology=False)

# %% [markdown]
# To better support the estimation of gradient (and may also assist in curvature), we should segmentize the data to have a maximum distance between points.

# %%
simple2_route = simple_route.segmentize(max_segment_length=200)
simple2_route = simple2_route.to_crs(4326)
len(simple2_route.geometry.get_coordinates())
# Out:
# 4607

# %%
len(simple2_route)
# Out:
# 277

# %% [markdown]
# We get the necessary altitudes at this point. This is a relative long process of querrying. The data in the dataframe consists of a number of line segments. In this case there are 277.

# %%
def curve(p1, p2, p3):
    v1=p2-p1
    v2=p3-p2
    v3=p1-p3
    d1=np.linalg.norm(v1)
    d2=np.linalg.norm(v2)
    d3=np.linalg.norm(v3)
    num = 1746.375*2*np.linalg.norm(np.cross(v1,v2))
    d = num/(d1*d2*d3)
    if d<0.01:
        d=0.0
    return d

# %%
route2_xy = route2_data.copy()

# %%
route2_ll = route2_data.to_crs(4326)

# %%
API_KEY="AIzaSyDUJLn3rph0_rVjdu0-yne0hig58qrTGXQ"

# %%
def get_alt(lat, lng):
    st = ""
    # print(lng)
    for i in range(len(lng)):
        st+=str(lat[i])+','+str(lng[i])+'|'
    st=st[:-1]
    url = "https://maps.googleapis.com/maps/api/elevation/json?locations=" + st + "&key=" + API_KEY
    # print(url)
    response = requests.get(url)
    # result = response.json()['results']['elevation']
    # print(response.status)
    # print(response.json()['results'])
    results = response.json()['results']
    res = []
    for rec in results:
        res.append(rec['elevation'])
    # should put in a test for response status before returning an actual value
    return res

# %% [raw]
# def get_alt(lat, lng):
#     # USGS Approach
#     res = []
#     for i in range(len(lng)):
#         lt = lat[i]
#         lg = lng[i]
#         url = "https://epqs.nationalmap.gov/v1/json?x=" + str(lg) + "&y=" + str(lt) + "&units=Meters&wkid=4326&includeDate=False"
#         response = requests.get(url)
#         print(response.status_code)
#         # print(response.text)
#         # should put in a test for response status before returning an actual value
#         if (response.status_code == 200):
#             # print(response.json())
#             if 'Invalid' in response.text:
#                 result = -1.0
#             else:
#                 result = float(response.json().get('value',0.0))
#         else:
#             result = 0.0
#         res.append(result)
#         print(lt, lg, result)
#     return res

# %%
codes = [d['code'] for d in railroads]
codes
# Out:
# ['BNSF', 'CN', 'CP', 'CSXT', 'NS', 'KCS', 'UP']

# %% [markdown]
# we need to explode the multiliestrings that are being used now to be linestrings

# %%
route2_xy.geometry=simple2_route.to_crs(3857)
route2_xy2 = route2_xy.explode(index_parts=True)

# %%
np.array(route2_xy2.iloc[0].geometry.coords)
# Out:
# array([[-9348464.41851551,  5027826.08330305],
#        [-9348406.09522865,  5027827.6896273 ]])

# %% [markdown]
# Test to add one row

# %%
route2_ll.geometry=simple2_route
route2_ll2 = route2_ll.explode(index_parts=True)
np.array(route2_ll2.iloc[0].geometry.coords)
# Out:
# array([[-83.9786847 ,  41.10489566],
#        [-83.97816077,  41.10490653]])

# %%
def create_row(rowxy, rowll, rights, url, token=None):
    p = np.array(rowxy.geometry.coords)
    pxy = p[:,0:2]
    # we want the interpoint distance between the points - the offset of 1, diagonal of the cdist matrix
    dist = np.diagonal(distance.cdist(pxy, pxy), offset=1)
    lng,lat = rowll.geometry.xy
    ele=get_alt(lat, lng)
    lnglat = np.array(rowll.geometry.coords)
    dele = np.diff(ele)
    gradient = np.divide(dele, dist)
    curvature=[]
    if (len(pxy)>2):
        for i in range(len(pxy)-2):
            curvature.append(curve(pxy[i],pxy[i+1],pxy[i+2]))
        curvature.append(curvature[-1])
    else:
        curvature = [0.0]
    line = {
        "fra_id" : rowxy['fraarcid'],
        "from_node" : rowxy['frfranode'],
        "to_node" : rowxy['tofranode'],
        "length" :dist.sum(),
        "rights" : rights,
        "net": rowxy['net'],
        "xy": pxy.tolist(),
        "elevation": ele,
        "lnglat": lnglat.tolist(),
        "gradient": gradient.tolist(),
        "curvature": curvature,
        "distance":dist.tolist()
    }
    requests.post(url, data=line, auth=TokenAuth(token))
    print(line['fra_id'])

# %%
create_row(route2_xy2.iloc[0], route2_ll2.iloc[0], [5], URL2, token)
# Out:
# 390312

# %%
for i in range(len(route2_xy2)):
    # first test to see if it already exists
    fra_id = route2_xy2.iloc[i]['fraarcid']
    response = requests.get(URL4+str(fra_id), auth=TokenAuth(token))
    # if (response.status_code == 204):
    create_row(route2_xy2.iloc[i], route2_ll2.iloc[i], [5], URL2, token)
    # print(route2_xy2.iloc[i][['fraarcid','frfranode', 'tofranode','net','miles']])
# Out:
# 390312
# 390313
# 390346
# 390351
# 390630
# 393188
# 393191
# 393683
# 393848
# 393869
# 393904
# 393907
# 397438
# 398448
# 398477
# 398483
# 398485
# 398486
# 398488
# 398489
# 398490
# 398556
# 398568
# 398641
# 399009
# 399017
# 399088
# 399092
# 399093
# 399094
# 399095
# 399096
# 399099
# 399118
# 399237
# 399407
# 399408
# 399411
# 399517
# 399523
# 399524
# 399550
# 399551
# 399552
# 399554
# 399561
# 399565
# 399566
# 399806
# 399807
# 399808
# 399824
# 399862
# 399863
# 399869
# 399870
# 399886
# 400031
# 400036
# 400058
# 400059
# 400060
# 400061
# 400062
# 400101
# 400102
# 400107
# 400198
# 400199
# 400212
# 400250
# 400318
# 400359
# 400458
# 400472
# 400491
# 400541
# 536682
# 400625
# 400660
# 400719
# 400736
# 400737
# 400738
# 400739
# 400740
# 400741
# 400807
# 400808
# 400809
# 400810
# 400812
# 400813
# 400883
# 401046
# 401105
# 401106
# 401107
# 401109
# 401195
# 401204
# 401205
# 401207
# 401215
# 401282
# 401493
# 401555
# 401556
# 401557
# 401558
# 401559
# 401870
# 401872
# 401907
# 401969
# 401970
# 401971
# 402196
# 402350
# 402397
# 402794
# 403080
# 403082
# 403083
# 403220
# 403285
# 403286
# 403335
# 403427
# 403671
# 403733
# 403774
# 405716
# 406351
# 406579
# 406698
# 406701
# 406735
# 407842
# 408027
# 408035
# 408036
# 408037
# 418671
# 422379
# 422400
# 422411
# 422440
# 422506
# 422562
# 422564
# 422583
# 422848
# 489678
# 489679
# 489680
# 490007
# 490676
# 491092
# 491093
# 491513
# 492346
# 492553
# 492557
# 492558
# 493010
# 493029
# 493030
# 493031
# 493073
# 493112
# 493730
# 493768
# 493773
# 493952
# 494126
# 494127
# 494138
# 494140
# 494152
# 494163
# 494249
# 494250
# 494315
# 494330
# 494340
# 494365
# 494398
# 494405
# 494475
# 494501
# 494506
# 494507
# 494667
# 494668
# 494702
# 494708
# 494709
# 494711
# 494714
# 494753
# 494757
# 494758
# 494759
# 494760
# 494761
# 494792
# 494793
# 494839
# 494920
# 494938
# 494939
# 494940
# 494947
# 494948
# 494956
# 494983
# 494987
# 494991
# 494992
# 495041
# 495044
# 495048
# 495052
# 495510
# 495514
# 495582
# 495632
# 495633
# 495636
# 495649
# 495650
# 495712
# 495765
# 495800
# 496025
# 496242
# 496747
# 496753
# 496755
# 496758
# 496768
# 497950
# 498769
# 499299
# 499471
# 499472
# 499779
# 500094
# 500999
# 501010
# 501114
# 501115
# 501116
# 501128
# 501332
# 501333
# 502245
# 502249
# 502270
# 502295
# 502338
# 502371
# 502372
# 502373
# 502661
# 502813
# 505387
# 505390
# 505396
# 507067
# 507375
# 519032
# 523795
# 529489
# 530850
# 536681

# %% [markdown]
# The next step to saving a route is to include an  ordered list of nodes used make the route.

# %%
len(route2_xy2)
# Out:
# 277

# %%
response = requests.get(URL6, auth=TokenAuth(token))

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'results': [{'id': 2, 'name': 'Rickenbacker'},
#   {'id': 4, 'name': 'Norfolk'},
#   {'id': 3, 'name': 'Croxton'},
#   {'id': 6, 'name': 'Savannah'},
#   {'id': 7, 'name': 'Macon'},
#   {'id': 8, 'name': 'Tyrone'},
#   {'id': 9, 'name': 'State College'},
#   {'id': 5, 'name': 'Suffolk'},
#   {'id': 10, 'name': 'Croxton'},
#   {'id': 1, 'name': 'Landers Yard'},
#   {'id': 11, 'name': 'Bethlehem Intermodal'},
#   {'id': 12, 'name': 'Rutherford Intermodal'},
#   {'id': 13, 'name': 'Pitcairn Intermodal'},
#   {'id': 14, 'name': 'Maple Heights Intermodal'},
#   {'id': 15, 'name': '47th Street Intermodal'}]}

# %%
route = {
    'origin': 15,
    'destination': 14,
    'owner': 5,
    'path': route2
}

# %%
res = requests.post(URL5, data=route, auth=TokenAuth(token))

# %%
res.json()
# Out:
# {'results': 5}

# %%
response = requests.get(URL8+'5', auth=TokenAuth(token))

# %%
response.status_code
# Out:
# 200

# %%
segments=response.json()['results']['segments']

# %%
start_elevation = response.json()['results']['start_elevation']

# %% [markdown]
# We can push the data into a Pandas dataframe easily.

# %%
seg_df = pd.DataFrame(segments)

# %%
seg_df
# Out:
#           length   degrees  gradient       distance  max_speed   elevation  \
# 0      71.435144  0.582265  0.006431      71.435144         60  183.836716
# 1     190.945471  0.000000 -0.003800     262.380615         60  183.111115
# 2     190.945471  0.000000  0.006045     453.326086         60  184.265396
# 3     190.945471  0.303120  0.004211     644.271557         60  185.069473
# 4     111.042237  1.533936  0.014454     755.313794         60  186.674454
# ...          ...       ...       ...            ...        ...         ...
# 4042  185.976346  0.279645  0.003649  731409.447568         60  272.639191
# 4043  161.076634  0.000000  0.004430  731570.524202         60  273.352722
# 4044  161.076634  0.000000  0.004001  731731.600836         60  273.997192
# 4045  161.076634  0.000000  0.002629  731892.677470         60  274.420593
# 4046  161.076634  0.000000  0.005038  732053.754105         60  275.232117
#
#       order
# 0         0
# 1         1
# 2         2
# 3         3
# 4         4
# ...     ...
# 4042   4042
# 4043   4043
# 4044   4044
# 4045   4045
# 4046   4046
#
# [4047 rows x 7 columns]

# %%
seg_df.plot(x="distance", y="elevation")
# Out:
# <Axes: xlabel='distance'>

# %%
seg_df.plot(x="distance", y="gradient")
# Out:
# <Axes: xlabel='distance'>

# %%
def savgol_nonuniform(x, y, window_length, polyorder, deriv=0):
    """
    Savitzky-Golay smoothing 1D filter

    :param x:
    :param y:
    :param window_length: the smoothing sample, e.g. window_length=2 for smoothing over 5 points
    :param polyorder: the degree of the local polynomial fit, e.g. polyorder=2 for a parabolic fit
    :param deriv: The order of the derivative to compute. This must be a nonnegative integer.
            The default is 0, which means to filter the data without differentiating.
    :return:
    """
    if type(x) is not np.array:
        x = np.array(x)
    if type(y) is not np.array:
        y = np.array(y)

    n = int((window_length - 1) / 2)

    if x.shape != y.shape:
        raise RuntimeError("x and y arrays are of different shape")
    if x.shape[0] < window_length:
        raise RuntimeError("not enough data to start the smoothing process")
    if 2 * n + 1 <= polyorder + 1:
        raise RuntimeError("need at least deg+1 points to make the polynomial")

    # smooth start and end data
    ysm = np.zeros(y.shape)
    for i in range(n):
        j = y.shape[0] - i - 1
        if deriv == 0:
            ysm[i] = y[i]
            ysm[j] = y[j]
        if deriv == 1:
            ysm[i] = (y[i] - y[i - 1]) / (x[i] - x[i - 1])
            ysm[j] = (y[j] - y[j - 1]) / (x[j] - x[j - 1])
        if deriv == 2:
            ysm[i] = (((y[i] - y[i - 1]) / (x[i] - x[i - 1])) - ((y[i - 1] - y[i - 2]) / (x[i - 1] - x[i - 2]))) / \
                     (x[i] - x[i - 1])
            ysm[j] = (((y[j] - y[j - 1]) / (x[j] - x[j - 1])) - ((y[j - 1] - y[j - 2]) / (x[j - 1] - x[j - 2]))) / \
                     (x[j] - x[j - 1])
        if deriv >= 3:
            raise NotImplementedError("derivatives >= 3 not implemented")

    m = 2 * n + 1  # the size of the filter window
    o = polyorder + 1  # the smoothing order
    A = np.zeros((m, o))  # A matrix
    t = np.zeros(m)
    # start smoothing
    for i in range(n, x.shape[0] - n):
        for j in range(m):
            t[j] = x[i + j - n] - x[i]
        for j in range(m):
            r = 1.0
            for k in range(o):
                A[j, k] = r
                r *= t[j]
        tA = A.transpose()  # A transposed
        tAA = np.matmul(tA, A)  # make tA.A
        tAA = np.linalg.inv(tAA)  # make (tA.A)-¹ in place
        tAAtA = np.matmul(tAA, tA)  # make (tA.A)-¹.tA

        # compute the polynomial's value at the center of the sample
        ysm[i] = 0.0
        for j in range(m):
            ysm[i] += tAAtA[deriv, j] * y[i + j - n]

    return ysm

# %%
x=np.insert(np.array(seg_df['distance']),0,0.0,axis=0)

# %%
y=np.insert(np.array(seg_df['elevation']),0, start_elevation, axis=0)

# %%
new_elevations = savgol_nonuniform(x,y, 13, 3, 0)
seg_df['new_elevations']=new_elevations[1:]

# %%
plt.figure(figsize=(16, 8))
seg_df.plot(x="distance", y=["elevation","new_elevations"])
# Out:
# <Axes: xlabel='distance'>

# %%
from scipy.signal import savgol_filter

# %%
new_elevations2 = savgol_filter(x, 35, 3, 0)
seg_df['new_elevations']=new_elevations2[1:]

# %%
dele = np.diff(new_elevations)
len(dele)
# Out:
# 4047

# %%
delx = np.diff(x)
len(delx)
# Out:
# 4047

# %%
temp=delx-np.array(seg_df['length'])
temp.sum()
# Out:
# -1.3636132223382447e-09

# %%
grads = np.divide(dele, delx)

# %%
grads.max()
# Out:
# 0.031200105154634616

# %%
seg_df.gradient=grads

# %%
seg_df.plot(x="distance", y="new_elevations")
# Out:
# <Axes: xlabel='distance'>

# %%
seg_df.plot(x="distance", y="gradient")
# Out:
# <Axes: xlabel='distance'>

# %%
seg_df.plot(x="distance", y="gradient")
# Out:
# <Axes: xlabel='distance'>
